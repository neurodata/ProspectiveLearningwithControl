# %%
import numpy as np
import sys
sys.path.append("../src")
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import glob
import os
from utils import time_embedding_np, reward_simulate,simulate_data_raw,make_weighted_target,position_encoder
from utils import best_next_state,path_opt,preward_opt,compute_normalized_future_rewards
from treeple.experimental import StreamDecisionForest
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import xgboost as xgb

# %%
base_reward = 10.0
map_name = "short"
decay_rate = 0.6
reward_period = 10 
session_duration = 500000
rewards_in_period = []

total_steps = session_duration
for period_start in range(0, total_steps, reward_period):
    period_end = min(period_start + reward_period, total_steps)
    steps_in_period = np.arange(period_start, period_end)
    rewards_in_period.extend(base_reward * (decay_rate ** (steps_in_period - period_start)))

pattern = [1,1,1,1,1,1,1,2,3,4,5,5,5,5,5,5,5,4,3,2]
optimal_states = np.array(pattern*(session_duration // len(pattern))).reshape(-1,1)

# %%
def get_candidates(state, t):
    if state == 0:
        return [1, 0]
    elif state == 6:
        return [5, 6]
    else:
        # default 3-way split for illustration
        return [state-1, state, state+1]

def enumerate_paths(x0, t_inital = 0, t_prime=20):
    paths = [[x0]]
    for t in range(t_prime):
        new_paths = []
        for path in paths:
            curr = path[-1]
            for nxt in get_candidates(curr, t):
                new_paths.append(path + [nxt])
        paths = new_paths
    
    # Convert to DataFrame: each row is one path, columns t=0..T
    cols = [f"t={t_inital+i}" for i in range(t_prime+1)]
    df = pd.DataFrame(paths, columns=cols)
    return df

# %%
def train_model(X, Y, rf=None, sample_weight = None):
    """Train or continue training the XGBRegressor."""
    if rf is None:
        rf = xgb.XGBRegressor(
            objective="reg:squarederror",
            tree_method="exact",
            n_jobs=-1,
            learning_rate=0.05, max_depth=10,
            subsample=1, colsample_bytree=0.8,
            n_estimators=1000, eval_metric="rmse"
        )
        if sample_weight is None:
            rf.fit(X, Y)
        else:
            rf.fit(X, Y,sample_weight = sample_weight)
    else:
        if sample_weight is None:
            rf.fit(X, Y)
        else:
            rf.fit(X, Y,sample_weight = sample_weight)
    return rf

def predict_paths(rf, df_paths, t_start, t_prime):
    n_paths = df_paths.shape[0]
    preds = np.zeros((n_paths, t_prime+1))
    for i in range(t_prime+1):
        if df_paths.shape[1] == 1:
            cand_pe = position_encoder(df_paths, type="onehot")
        else:
            cand_pe = position_encoder(df_paths.iloc[:,i], type="onehot")
        curr_time = t_start + 1 + i
        time_emb = time_embedding_np(np.ones(cand_pe.shape[0]) * curr_time, tdim=50)
        features = np.hstack([cand_pe, time_emb])
        preds[:, i] = rf.predict(features)
    return preds

def choose_next_state(rf_action, rf_value, current_state, t_now, t_prime_action, t_prime_value, gamma):
    """Pick best next state based on discounted rewards."""
    df_paths = enumerate_paths(x0=current_state, t_inital=t_now, t_prime=t_prime_action)
    df_paths_value = np.asarray(df_paths.iloc[:,-1]).reshape(-1,1)

    preds_action = predict_paths(rf_action, df_paths, t_now, t_prime_action)
    preds_value = predict_paths(rf_value, df_paths_value, t_now+t_prime_action ,t_prime_value)

    rewards_matrix = preds_action[:, 1:]
    rewards_matrix = np.hstack([rewards_matrix,preds_value])

    discounts = gamma ** np.arange(0, t_prime_action+1) # Make t_prime_value = 1
    total_disc = (rewards_matrix * discounts).sum(axis=1)
    best_idx = np.argmax(total_disc)

    return int(df_paths.iloc[best_idx, 1]), df_paths, rewards_matrix

def run_inference(rf_action, rf_value, start_state, T_p, t_prime_action, t_prime_value, gamma, rewards_in_period, epsilon = 0.1):
    """Generate future trajectory and compute regret."""
    current_state = start_state
    future_states = [current_state]

    for delta_t in range(100):
        next_state, df_paths, preds = choose_next_state(rf_action, rf_value, current_state, T_p + delta_t, t_prime_action, t_prime_value, gamma)
        if np.random.rand() < epsilon:
            candidates = get_candidates(current_state, T_p + delta_t)
            next_state = np.random.choice(candidates)
        future_states.append(next_state)
        current_state = next_state

    # compute rewards
    irewards_test = [reward_simulate(future_states[i], T_p+i, rewards_in_period) 
                     for i in range(1, len(future_states))]
    preward = compute_normalized_future_rewards(irewards_test, 100, gamma,normalization=True)

    # optimal path benchmark
    path, ireward_opt = path_opt(future_states[0], T_p, 100)
    preward_opt_test = compute_normalized_future_rewards(ireward_opt[1:], 100, gamma,normalization=True)

    pregret = (np.sum(preward_opt_test).item() - np.sum(preward).item()) / 100

    return pregret,preds

# %%
T = 200
gamma = 0.9
t_prime_action = 6
t_prime_value = 0
threshold = 1e-4
DELTA_T = 1000
PREGRETS = []
epsilon = 0.1

for rep in range(10):
    # one simulation per rep
    actions, states, irewards, times = simulate_data_raw(
        rewards_in_period=rewards_in_period,
        session_duration=2000,
        tdim=50, n_sessions=1, seed=515+rep
    )
    prewards = make_weighted_target(irewards, gamma,T = T,normalization = False)

    # initial dataset
    X_train = np.hstack([position_encoder(states[:T,0], type="onehot"), states[:T,1:]])
    Y_train_action = irewards[:T]
    rf_action = train_model(X_train, Y_train_action, None)

    Y_train_value = prewards

    rf_value = train_model(X_train, Y_train_value)
    print(Y_train_value.shape)
    
    PREGRET = []
    current_state = states[T,0]
    for delta_t in range(1,DELTA_T+1):
        next_state, df_paths, preds = choose_next_state(rf_action,rf_value, current_state, T+delta_t, t_prime_action, t_prime_value, gamma)
        if np.random.rand() < epsilon:
            candidates = get_candidates(current_state, T+delta_t)
            next_state = np.random.choice(candidates)

        next_time = T+1+delta_t
        next_features = np.hstack([
            position_encoder(np.array([next_state]), type="onehot"),
            time_embedding_np(next_time, tdim=50).reshape(1,-1)
        ])
        next_reward = reward_simulate(next_state, next_time-1, rewards_in_period)

        ## PolicyIteration
        X_train = np.vstack([X_train, next_features])
        Y_train_action = np.vstack([Y_train_action.reshape(-1,1), [[next_reward]]])

        rf_action = train_model(X_train, Y_train_action, rf_action)

        Y_train_value = make_weighted_target(Y_train_action, gamma ,T = T+delta_t,normalization = False)
 
        rf_value = train_model(X_train, Y_train_value)
        
        current_state = next_state  # move forward

    
        T_p = delta_t + T
        start_state = current_state
        pregret_val,pred = run_inference(rf_action, rf_value, start_state, T_p,  t_prime_action, t_prime_value, gamma, rewards_in_period)
        print(f"rep {rep}, T_train {T_p}, pregret={pregret_val:.4f}")
        PREGRET.append(pregret_val)

    PREGRETS.append(PREGRET)
# Out:
# (200,)
# rep 0, T_train 201, pregret=0.5970
# rep 0, T_train 202, pregret=0.6014
# rep 0, T_train 203, pregret=0.2150
# rep 0, T_train 204, pregret=0.6292
# rep 0, T_train 205, pregret=0.3555
# rep 0, T_train 206, pregret=0.5990
# rep 0, T_train 207, pregret=0.3766
# rep 0, T_train 208, pregret=0.1368
# rep 0, T_train 209, pregret=0.4561
# rep 0, T_train 210, pregret=0.6906
# rep 0, T_train 211, pregret=0.3796
# rep 0, T_train 212, pregret=0.1921
# rep 0, T_train 213, pregret=0.3791
# rep 0, T_train 214, pregret=0.2663
# rep 0, T_train 215, pregret=0.3401
# rep 0, T_train 216, pregret=0.3765
# rep 0, T_train 217, pregret=0.3352
# rep 0, T_train 218, pregret=0.8321
# rep 0, T_train 219, pregret=0.4450
# rep 0, T_train 220, pregret=0.2612
# rep 0, T_train 221, pregret=0.9183
# rep 0, T_train 222, pregret=0.2985
# rep 0, T_train 223, pregret=0.9048
# rep 0, T_train 224, pregret=0.3011
# rep 0, T_train 225, pregret=0.6333
# rep 0, T_train 226, pregret=0.2982
# rep 0, T_train 227, pregret=0.6158
# rep 0, T_train 228, pregret=0.7570
# rep 0, T_train 229, pregret=0.2023
# rep 0, T_train 230, pregret=0.1150
# rep 0, T_train 231, pregret=0.3615
# rep 0, T_train 232, pregret=0.3054
# rep 0, T_train 233, pregret=0.4300
# rep 0, T_train 234, pregret=0.8273
# rep 0, T_train 235, pregret=0.4579
# rep 0, T_train 236, pregret=0.4926
# rep 0, T_train 237, pregret=0.9087
# rep 0, T_train 238, pregret=0.2390
# rep 0, T_train 239, pregret=0.4070
# rep 0, T_train 240, pregret=0.6227
# rep 0, T_train 241, pregret=0.1889
# rep 0, T_train 242, pregret=0.5754
# rep 0, T_train 243, pregret=0.5881
# rep 0, T_train 244, pregret=0.1137
# rep 0, T_train 245, pregret=0.6310
# rep 0, T_train 246, pregret=0.1775
# rep 0, T_train 247, pregret=0.5452
# rep 0, T_train 248, pregret=0.4749
# rep 0, T_train 249, pregret=0.0842
# rep 0, T_train 250, pregret=0.8307
# rep 0, T_train 251, pregret=0.0448
# rep 0, T_train 252, pregret=0.7273
# rep 0, T_train 253, pregret=0.2952
# rep 0, T_train 254, pregret=1.0447
# rep 0, T_train 255, pregret=0.7319
# rep 0, T_train 256, pregret=1.0102
# rep 0, T_train 257, pregret=0.2013
# rep 0, T_train 258, pregret=0.4323
# rep 0, T_train 259, pregret=0.4923
# rep 0, T_train 260, pregret=0.3635
# rep 0, T_train 261, pregret=0.5979
# rep 0, T_train 262, pregret=0.2127
# rep 0, T_train 263, pregret=0.2812
# rep 0, T_train 264, pregret=0.3650
# rep 0, T_train 265, pregret=0.5599
# rep 0, T_train 266, pregret=0.4045
# rep 0, T_train 267, pregret=0.2821
# rep 0, T_train 268, pregret=0.4244
# rep 0, T_train 269, pregret=0.2544
# rep 0, T_train 270, pregret=0.1241
# rep 0, T_train 271, pregret=0.5722
# rep 0, T_train 272, pregret=0.6872
# rep 0, T_train 273, pregret=0.4112
# rep 0, T_train 274, pregret=0.8761
# rep 0, T_train 275, pregret=0.2989
# rep 0, T_train 276, pregret=0.1212
# rep 0, T_train 277, pregret=0.1953
# rep 0, T_train 278, pregret=1.0651
# rep 0, T_train 279, pregret=0.3400
# rep 0, T_train 280, pregret=0.2476
# rep 0, T_train 281, pregret=0.2374
# rep 0, T_train 282, pregret=0.7736
# rep 0, T_train 283, pregret=0.4040
# rep 0, T_train 284, pregret=0.4673
# rep 0, T_train 285, pregret=0.3584
# rep 0, T_train 286, pregret=0.4364
# rep 0, T_train 287, pregret=0.3629
# rep 0, T_train 288, pregret=0.3101
# rep 0, T_train 289, pregret=0.4206
# rep 0, T_train 290, pregret=0.2624
# rep 0, T_train 291, pregret=0.5234
# rep 0, T_train 292, pregret=0.1895
# rep 0, T_train 293, pregret=0.4441
# rep 0, T_train 294, pregret=0.3230
# rep 0, T_train 295, pregret=0.3796
# rep 0, T_train 296, pregret=0.6369
# rep 0, T_train 297, pregret=0.2289
# rep 0, T_train 298, pregret=0.5268
# rep 0, T_train 299, pregret=0.2300
# rep 0, T_train 300, pregret=1.1506
# rep 0, T_train 301, pregret=0.6456
# rep 0, T_train 302, pregret=0.5538
# rep 0, T_train 303, pregret=0.5995
# rep 0, T_train 304, pregret=0.3567
# rep 0, T_train 305, pregret=0.3855
# rep 0, T_train 306, pregret=0.6759
# rep 0, T_train 307, pregret=0.9495
# rep 0, T_train 308, pregret=0.4008
# rep 0, T_train 309, pregret=0.3000
# rep 0, T_train 310, pregret=0.2937
# rep 0, T_train 311, pregret=0.3891
# rep 0, T_train 312, pregret=0.2677
# rep 0, T_train 313, pregret=0.0986
# rep 0, T_train 314, pregret=0.2803
# rep 0, T_train 315, pregret=0.7027
# rep 0, T_train 316, pregret=0.4873
# rep 0, T_train 317, pregret=0.4799
# rep 0, T_train 318, pregret=0.6135
# rep 0, T_train 319, pregret=0.3250
# rep 0, T_train 320, pregret=0.5095
# rep 0, T_train 321, pregret=0.9705
# rep 0, T_train 322, pregret=0.8504
# rep 0, T_train 323, pregret=0.5046
# rep 0, T_train 324, pregret=0.5537
# rep 0, T_train 325, pregret=0.1583
# rep 0, T_train 326, pregret=0.5206
# rep 0, T_train 327, pregret=0.7586
# rep 0, T_train 328, pregret=0.3883
# rep 0, T_train 329, pregret=0.2542
# rep 0, T_train 330, pregret=0.6300
# rep 0, T_train 331, pregret=0.4440
# rep 0, T_train 332, pregret=0.8771
# rep 0, T_train 333, pregret=0.7150
# rep 0, T_train 334, pregret=0.1816
# rep 0, T_train 335, pregret=1.0599
# rep 0, T_train 336, pregret=0.1824
# rep 0, T_train 337, pregret=0.5152
# rep 0, T_train 338, pregret=0.6890
# rep 0, T_train 339, pregret=0.3175
# rep 0, T_train 340, pregret=0.5451
# rep 0, T_train 341, pregret=0.7805
# rep 0, T_train 342, pregret=0.5684
# rep 0, T_train 343, pregret=0.8014
# rep 0, T_train 344, pregret=0.2638
# rep 0, T_train 345, pregret=0.3627
# rep 0, T_train 346, pregret=0.1310
# rep 0, T_train 347, pregret=0.3960
# rep 0, T_train 348, pregret=0.7370
# rep 0, T_train 349, pregret=0.2417
# rep 0, T_train 350, pregret=0.6543
# rep 0, T_train 351, pregret=0.2377
# rep 0, T_train 352, pregret=0.5441
# rep 0, T_train 353, pregret=0.5174
# rep 0, T_train 354, pregret=0.6926
# rep 0, T_train 355, pregret=0.4586
# rep 0, T_train 356, pregret=0.5132
# rep 0, T_train 357, pregret=0.5784
# rep 0, T_train 358, pregret=0.0543
# rep 0, T_train 359, pregret=0.2783
# rep 0, T_train 360, pregret=0.5816
# rep 0, T_train 361, pregret=0.1638
# rep 0, T_train 362, pregret=0.1690
# rep 0, T_train 363, pregret=0.1510
# rep 0, T_train 364, pregret=0.3570
# rep 0, T_train 365, pregret=0.3577
# rep 0, T_train 366, pregret=0.4564
# rep 0, T_train 367, pregret=0.6079
# rep 0, T_train 368, pregret=0.0933
# rep 0, T_train 369, pregret=0.3281
# rep 0, T_train 370, pregret=0.2162
# rep 0, T_train 371, pregret=0.7049
# rep 0, T_train 372, pregret=0.7053
# rep 0, T_train 373, pregret=0.7688
# rep 0, T_train 374, pregret=0.9022
# rep 0, T_train 375, pregret=0.1950
# rep 0, T_train 376, pregret=0.5173
# rep 0, T_train 377, pregret=0.1716
# rep 0, T_train 378, pregret=0.1892
# rep 0, T_train 379, pregret=0.7031
# rep 0, T_train 380, pregret=0.5432
# rep 0, T_train 381, pregret=0.4819
# rep 0, T_train 382, pregret=1.2134
# rep 0, T_train 383, pregret=0.2978
# rep 0, T_train 384, pregret=0.6228
# rep 0, T_train 385, pregret=0.7950
# rep 0, T_train 386, pregret=0.4640
# rep 0, T_train 387, pregret=0.2773
# rep 0, T_train 388, pregret=0.2473
# rep 0, T_train 389, pregret=0.3764
# rep 0, T_train 390, pregret=0.2990
# rep 0, T_train 391, pregret=0.3311
# rep 0, T_train 392, pregret=0.2520
# rep 0, T_train 393, pregret=0.6670
# rep 0, T_train 394, pregret=0.0879
# rep 0, T_train 395, pregret=0.3609
# rep 0, T_train 396, pregret=0.0463
# rep 0, T_train 397, pregret=0.6865
# rep 0, T_train 398, pregret=0.8409
# rep 0, T_train 399, pregret=0.9251
# rep 0, T_train 400, pregret=0.2103
# rep 0, T_train 401, pregret=0.2868
# rep 0, T_train 402, pregret=0.4058
# rep 0, T_train 403, pregret=0.1668
# rep 0, T_train 404, pregret=0.3485
# rep 0, T_train 405, pregret=0.4504
# rep 0, T_train 406, pregret=0.4869
# rep 0, T_train 407, pregret=0.2343
# rep 0, T_train 408, pregret=0.6395
# rep 0, T_train 409, pregret=0.6118
# rep 0, T_train 410, pregret=0.4062
# rep 0, T_train 411, pregret=0.3751
# rep 0, T_train 412, pregret=0.6471
# rep 0, T_train 413, pregret=0.4073
# rep 0, T_train 414, pregret=0.6143
# rep 0, T_train 415, pregret=0.7936
# rep 0, T_train 416, pregret=0.2690
# rep 0, T_train 417, pregret=0.2462
# rep 0, T_train 418, pregret=0.3804
# rep 0, T_train 419, pregret=0.0534
# rep 0, T_train 420, pregret=0.6728
# rep 0, T_train 421, pregret=0.9681
# rep 0, T_train 422, pregret=0.7827
# rep 0, T_train 423, pregret=0.2800
# rep 0, T_train 424, pregret=0.3629
# rep 0, T_train 425, pregret=0.5310
# rep 0, T_train 426, pregret=0.4066
# rep 0, T_train 427, pregret=0.3492
# rep 0, T_train 428, pregret=0.2898
# rep 0, T_train 429, pregret=0.6008
# rep 0, T_train 430, pregret=0.6944
# rep 0, T_train 431, pregret=0.3770
# rep 0, T_train 432, pregret=0.5601
# rep 0, T_train 433, pregret=0.6737
# rep 0, T_train 434, pregret=0.3140
# rep 0, T_train 435, pregret=0.1710
# rep 0, T_train 436, pregret=0.7748
# rep 0, T_train 437, pregret=0.1847
# rep 0, T_train 438, pregret=0.4522
# rep 0, T_train 439, pregret=0.4723
# rep 0, T_train 440, pregret=0.8542
# rep 0, T_train 441, pregret=0.4860
# rep 0, T_train 442, pregret=0.2007
# rep 0, T_train 443, pregret=0.6599
# rep 0, T_train 444, pregret=0.6932
# rep 0, T_train 445, pregret=0.2064
# rep 0, T_train 446, pregret=0.3578
# rep 0, T_train 447, pregret=0.7125
# rep 0, T_train 448, pregret=0.1606
# rep 0, T_train 449, pregret=0.4928
# rep 0, T_train 450, pregret=0.4183
# rep 0, T_train 451, pregret=0.3005
# rep 0, T_train 452, pregret=0.4256
# rep 0, T_train 453, pregret=0.5697
# rep 0, T_train 454, pregret=0.2679
# rep 0, T_train 455, pregret=0.5330
# rep 0, T_train 456, pregret=0.4513
# rep 0, T_train 457, pregret=0.2103
# rep 0, T_train 458, pregret=0.4189
# rep 0, T_train 459, pregret=0.4953
# rep 0, T_train 460, pregret=0.4932
# rep 0, T_train 461, pregret=0.7840
# rep 0, T_train 462, pregret=0.6348
# rep 0, T_train 463, pregret=0.4216
# rep 0, T_train 464, pregret=0.8862
# rep 0, T_train 465, pregret=0.7288
# rep 0, T_train 466, pregret=0.4853
# rep 0, T_train 467, pregret=0.5460
# rep 0, T_train 468, pregret=0.1882
# rep 0, T_train 469, pregret=0.3282
# rep 0, T_train 470, pregret=0.7376
# rep 0, T_train 471, pregret=0.9392
# rep 0, T_train 472, pregret=0.3702
# rep 0, T_train 473, pregret=0.8248
# rep 0, T_train 474, pregret=0.1762
# rep 0, T_train 475, pregret=0.6423
# rep 0, T_train 476, pregret=0.4457
# rep 0, T_train 477, pregret=0.3785
# rep 0, T_train 478, pregret=0.5555
# rep 0, T_train 479, pregret=0.4882
# rep 0, T_train 480, pregret=0.7045
# rep 0, T_train 481, pregret=0.5554
# rep 0, T_train 482, pregret=0.2890
# rep 0, T_train 483, pregret=0.6088
# rep 0, T_train 484, pregret=0.7999
# rep 0, T_train 485, pregret=0.6915
# rep 0, T_train 486, pregret=0.1747
# rep 0, T_train 487, pregret=0.3177
# rep 0, T_train 488, pregret=0.6210
# rep 0, T_train 489, pregret=0.5511
# rep 0, T_train 490, pregret=0.5887
# rep 0, T_train 491, pregret=0.4588
# rep 0, T_train 492, pregret=0.5214
# rep 0, T_train 493, pregret=0.4005
# rep 0, T_train 494, pregret=0.1394
# rep 0, T_train 495, pregret=0.5122
# rep 0, T_train 496, pregret=0.4758
# rep 0, T_train 497, pregret=0.4510
# rep 0, T_train 498, pregret=0.9926
# rep 0, T_train 499, pregret=0.1127
# rep 0, T_train 500, pregret=0.5286
# rep 0, T_train 501, pregret=0.4210
# rep 0, T_train 502, pregret=0.5680
# rep 0, T_train 503, pregret=0.3520
# rep 0, T_train 504, pregret=0.7386
# rep 0, T_train 505, pregret=0.6686
# rep 0, T_train 506, pregret=0.6790
# rep 0, T_train 507, pregret=0.4561
# rep 0, T_train 508, pregret=0.3703
# rep 0, T_train 509, pregret=0.2889
# rep 0, T_train 510, pregret=0.6275
# rep 0, T_train 511, pregret=0.6970
# rep 0, T_train 512, pregret=0.6527
# rep 0, T_train 513, pregret=0.3047
# rep 0, T_train 514, pregret=0.4130
# rep 0, T_train 515, pregret=0.3243
# rep 0, T_train 516, pregret=0.4759
# rep 0, T_train 517, pregret=0.2972
# rep 0, T_train 518, pregret=0.7239
# rep 0, T_train 519, pregret=0.3137
# rep 0, T_train 520, pregret=1.1591
# rep 0, T_train 521, pregret=0.7266
# rep 0, T_train 522, pregret=0.6401
# rep 0, T_train 523, pregret=1.0618
# rep 0, T_train 524, pregret=0.8876
# rep 0, T_train 525, pregret=0.5971
# rep 0, T_train 526, pregret=0.5886
# rep 0, T_train 527, pregret=0.3210
# rep 0, T_train 528, pregret=0.5184
# rep 0, T_train 529, pregret=0.6444
# rep 0, T_train 530, pregret=0.5547
# rep 0, T_train 531, pregret=0.6182
# rep 0, T_train 532, pregret=0.2927
# rep 0, T_train 533, pregret=0.3507
# rep 0, T_train 534, pregret=0.6959
# rep 0, T_train 535, pregret=0.7705
# rep 0, T_train 536, pregret=0.7712
# rep 0, T_train 537, pregret=0.7089
# rep 0, T_train 538, pregret=0.1010
# rep 0, T_train 539, pregret=0.2241
# rep 0, T_train 540, pregret=0.8509
# rep 0, T_train 541, pregret=0.8047
# rep 0, T_train 542, pregret=0.3177
# rep 0, T_train 543, pregret=0.2029
# rep 0, T_train 544, pregret=0.5545
# rep 0, T_train 545, pregret=0.3287
# rep 0, T_train 546, pregret=0.5228
# rep 0, T_train 547, pregret=0.5520
# rep 0, T_train 548, pregret=0.6784
# rep 0, T_train 549, pregret=0.5164
# rep 0, T_train 550, pregret=0.2447
# rep 0, T_train 551, pregret=0.3245
# rep 0, T_train 552, pregret=0.2482
# rep 0, T_train 553, pregret=0.1106
# rep 0, T_train 554, pregret=0.7679
# rep 0, T_train 555, pregret=0.2829
# rep 0, T_train 556, pregret=0.4582
# rep 0, T_train 557, pregret=0.1677
# rep 0, T_train 558, pregret=0.3865
# rep 0, T_train 559, pregret=0.1318
# rep 0, T_train 560, pregret=0.6701
# rep 0, T_train 561, pregret=0.5920
# rep 0, T_train 562, pregret=0.5449
# rep 0, T_train 563, pregret=0.1730
# rep 0, T_train 564, pregret=0.2758
# rep 0, T_train 565, pregret=0.3886
# rep 0, T_train 566, pregret=0.9389
# rep 0, T_train 567, pregret=0.0659
# rep 0, T_train 568, pregret=0.2956
# rep 0, T_train 569, pregret=0.5189
# rep 0, T_train 570, pregret=0.2679
# rep 0, T_train 571, pregret=0.7378
# rep 0, T_train 572, pregret=0.3177
# rep 0, T_train 573, pregret=0.2650
# rep 0, T_train 574, pregret=0.6294
# rep 0, T_train 575, pregret=0.4115
# rep 0, T_train 576, pregret=0.9426
# rep 0, T_train 577, pregret=0.5793
# rep 0, T_train 578, pregret=0.5309
# rep 0, T_train 579, pregret=0.5813
# rep 0, T_train 580, pregret=0.6772
# rep 0, T_train 581, pregret=0.7359
# rep 0, T_train 582, pregret=0.5377
# rep 0, T_train 583, pregret=0.2731
# rep 0, T_train 584, pregret=0.2529
# rep 0, T_train 585, pregret=0.6256
# rep 0, T_train 586, pregret=0.5491
# rep 0, T_train 587, pregret=0.6918
# rep 0, T_train 588, pregret=0.4942
# rep 0, T_train 589, pregret=0.2272
# rep 0, T_train 590, pregret=0.2527
# rep 0, T_train 591, pregret=0.5166
# rep 0, T_train 592, pregret=0.5053
# rep 0, T_train 593, pregret=0.4767
# rep 0, T_train 594, pregret=0.6321
# rep 0, T_train 595, pregret=0.9403
# rep 0, T_train 596, pregret=0.1326
# rep 0, T_train 597, pregret=0.2806
# rep 0, T_train 598, pregret=0.4033
# rep 0, T_train 599, pregret=0.3198
# rep 0, T_train 600, pregret=1.1043
# rep 0, T_train 601, pregret=0.8669
# rep 0, T_train 602, pregret=0.7440
# rep 0, T_train 603, pregret=0.2082
# rep 0, T_train 604, pregret=0.6077
# rep 0, T_train 605, pregret=0.3326
# rep 0, T_train 606, pregret=0.5790
# rep 0, T_train 607, pregret=0.0959
# rep 0, T_train 608, pregret=0.2360
# rep 0, T_train 609, pregret=0.0165
# rep 0, T_train 610, pregret=0.7733
# rep 0, T_train 611, pregret=0.5365
# rep 0, T_train 612, pregret=0.4509
# rep 0, T_train 613, pregret=0.3361
# rep 0, T_train 614, pregret=0.3574
# rep 0, T_train 615, pregret=0.4954
# rep 0, T_train 616, pregret=0.6162
# rep 0, T_train 617, pregret=0.2723
# rep 0, T_train 618, pregret=0.4400
# rep 0, T_train 619, pregret=0.1254
# rep 0, T_train 620, pregret=0.3120
# rep 0, T_train 621, pregret=0.7637
# rep 0, T_train 622, pregret=0.6945
# rep 0, T_train 623, pregret=0.4381
# rep 0, T_train 624, pregret=0.1834
# rep 0, T_train 625, pregret=0.3783
# rep 0, T_train 626, pregret=0.8752
# rep 0, T_train 627, pregret=0.3206
# rep 0, T_train 628, pregret=0.7447
# rep 0, T_train 629, pregret=0.5164
# rep 0, T_train 630, pregret=0.4630
# rep 0, T_train 631, pregret=0.3938
# rep 0, T_train 632, pregret=0.4387
# rep 0, T_train 633, pregret=0.4773
# rep 0, T_train 634, pregret=0.3858
# rep 0, T_train 635, pregret=0.2334
# rep 0, T_train 636, pregret=0.2322
# rep 0, T_train 637, pregret=0.6355
# rep 0, T_train 638, pregret=0.3381
# rep 0, T_train 639, pregret=0.3366
# rep 0, T_train 640, pregret=0.3055
# rep 0, T_train 641, pregret=0.5456
# rep 0, T_train 642, pregret=0.5827
# rep 0, T_train 643, pregret=0.4831
# rep 0, T_train 644, pregret=0.7242
# rep 0, T_train 645, pregret=0.8970
# rep 0, T_train 646, pregret=0.7295
# rep 0, T_train 647, pregret=0.2039
# rep 0, T_train 648, pregret=0.7591
# rep 0, T_train 649, pregret=0.3616
# rep 0, T_train 650, pregret=0.2778
# rep 0, T_train 651, pregret=0.7703
# rep 0, T_train 652, pregret=0.3031
# rep 0, T_train 653, pregret=0.3807
# rep 0, T_train 654, pregret=0.5677
# rep 0, T_train 655, pregret=0.3053
# rep 0, T_train 656, pregret=0.5303
# rep 0, T_train 657, pregret=0.2748
# rep 0, T_train 658, pregret=0.4733
# rep 0, T_train 659, pregret=0.2224
# rep 0, T_train 660, pregret=0.1569
# rep 0, T_train 661, pregret=0.2278
# rep 0, T_train 662, pregret=0.7255
# rep 0, T_train 663, pregret=0.2272
# rep 0, T_train 664, pregret=0.3365
# rep 0, T_train 665, pregret=0.4947
# rep 0, T_train 666, pregret=0.4967
# rep 0, T_train 667, pregret=0.3406
# rep 0, T_train 668, pregret=0.4729
# rep 0, T_train 669, pregret=0.4357
# rep 0, T_train 670, pregret=0.6029
# rep 0, T_train 671, pregret=0.9196
# rep 0, T_train 672, pregret=0.2654
# rep 0, T_train 673, pregret=0.3635
# rep 0, T_train 674, pregret=0.3062
# rep 0, T_train 675, pregret=0.8328
# rep 0, T_train 676, pregret=0.6520
# rep 0, T_train 677, pregret=0.3618
# rep 0, T_train 678, pregret=0.1740
# rep 0, T_train 679, pregret=0.2927
# rep 0, T_train 680, pregret=0.4988
# rep 0, T_train 681, pregret=0.3957
# rep 0, T_train 682, pregret=0.3599
# rep 0, T_train 683, pregret=0.8051
# rep 0, T_train 684, pregret=0.1828
# rep 0, T_train 685, pregret=0.3666
# rep 0, T_train 686, pregret=0.6505
# rep 0, T_train 687, pregret=0.8233
# rep 0, T_train 688, pregret=0.4768
# rep 0, T_train 689, pregret=0.0306
# rep 0, T_train 690, pregret=0.9634
# rep 0, T_train 691, pregret=0.2021
# rep 0, T_train 692, pregret=0.7857
# rep 0, T_train 693, pregret=0.3424
# rep 0, T_train 694, pregret=0.3236
# rep 0, T_train 695, pregret=0.9085
# rep 0, T_train 696, pregret=0.3338
# rep 0, T_train 697, pregret=0.7413
# rep 0, T_train 698, pregret=0.5312
# rep 0, T_train 699, pregret=0.1658
# rep 0, T_train 700, pregret=0.8278
# rep 0, T_train 701, pregret=0.9092
# rep 0, T_train 702, pregret=0.7092
# rep 0, T_train 703, pregret=0.7733
# rep 0, T_train 704, pregret=0.3215
# rep 0, T_train 705, pregret=0.6977
# rep 0, T_train 706, pregret=0.4805
# rep 0, T_train 707, pregret=0.4690
# rep 0, T_train 708, pregret=0.4130
# rep 0, T_train 709, pregret=0.3564
# rep 0, T_train 710, pregret=0.9045
# rep 0, T_train 711, pregret=0.5471
# rep 0, T_train 712, pregret=0.6235
# rep 0, T_train 713, pregret=0.7283
# rep 0, T_train 714, pregret=0.8031
# rep 0, T_train 715, pregret=0.4051
# rep 0, T_train 716, pregret=0.4974
# rep 0, T_train 717, pregret=0.6921
# rep 0, T_train 718, pregret=1.2087
# rep 0, T_train 719, pregret=0.7078
# rep 0, T_train 720, pregret=0.1233
# rep 0, T_train 721, pregret=0.4150
# rep 0, T_train 722, pregret=0.5391
# rep 0, T_train 723, pregret=0.6165
# rep 0, T_train 724, pregret=0.9374
# rep 0, T_train 725, pregret=0.5911
# rep 0, T_train 726, pregret=0.9215
# rep 0, T_train 727, pregret=0.8666
# rep 0, T_train 728, pregret=0.2278
# rep 0, T_train 729, pregret=0.6139
# rep 0, T_train 730, pregret=0.2300
# rep 0, T_train 731, pregret=0.3339
# rep 0, T_train 732, pregret=0.5577
# rep 0, T_train 733, pregret=0.4899
# rep 0, T_train 734, pregret=0.2792
# rep 0, T_train 735, pregret=0.6009
# rep 0, T_train 736, pregret=0.6950
# rep 0, T_train 737, pregret=0.3512
# rep 0, T_train 738, pregret=0.6170
# rep 0, T_train 739, pregret=0.5490
# rep 0, T_train 740, pregret=0.1989
# rep 0, T_train 741, pregret=0.7924
# rep 0, T_train 742, pregret=0.4531
# rep 0, T_train 743, pregret=0.4076
# rep 0, T_train 744, pregret=0.3740
# rep 0, T_train 745, pregret=0.2555
# rep 0, T_train 746, pregret=0.9536
# rep 0, T_train 747, pregret=0.5514
# rep 0, T_train 748, pregret=0.5040
# rep 0, T_train 749, pregret=0.4169
# rep 0, T_train 750, pregret=0.3986
# rep 0, T_train 751, pregret=0.2804
# rep 0, T_train 752, pregret=0.7009
# rep 0, T_train 753, pregret=0.2766
# rep 0, T_train 754, pregret=0.7292
# rep 0, T_train 755, pregret=0.8185
# rep 0, T_train 756, pregret=0.3264
# rep 0, T_train 757, pregret=1.0377
# rep 0, T_train 758, pregret=0.5672
# rep 0, T_train 759, pregret=0.2472
# rep 0, T_train 760, pregret=1.0925
# rep 0, T_train 761, pregret=0.3841
# rep 0, T_train 762, pregret=0.2088
# rep 0, T_train 763, pregret=0.3971
# rep 0, T_train 764, pregret=0.3370
# rep 0, T_train 765, pregret=0.1084
# rep 0, T_train 766, pregret=0.3844
# rep 0, T_train 767, pregret=0.5746
# rep 0, T_train 768, pregret=0.3572
# rep 0, T_train 769, pregret=0.6140
# rep 0, T_train 770, pregret=0.4201
# rep 0, T_train 771, pregret=0.5361
# rep 0, T_train 772, pregret=0.6477
# rep 0, T_train 773, pregret=0.8853
# rep 0, T_train 774, pregret=0.3031
# rep 0, T_train 775, pregret=0.5966
# rep 0, T_train 776, pregret=0.2512
# rep 0, T_train 777, pregret=0.6843
# rep 0, T_train 778, pregret=0.5372
# rep 0, T_train 779, pregret=0.1159
# rep 0, T_train 780, pregret=0.1195
# rep 0, T_train 781, pregret=1.0241
# rep 0, T_train 782, pregret=0.3545
# rep 0, T_train 783, pregret=0.2365
# rep 0, T_train 784, pregret=0.3450
# rep 0, T_train 785, pregret=0.4774
# rep 0, T_train 786, pregret=0.5823
# rep 0, T_train 787, pregret=1.0406
# rep 0, T_train 788, pregret=0.1787
# rep 0, T_train 789, pregret=0.3237
# rep 0, T_train 790, pregret=0.7394
# rep 0, T_train 791, pregret=0.2528
# rep 0, T_train 792, pregret=0.4721
# rep 0, T_train 793, pregret=0.2772
# rep 0, T_train 794, pregret=0.3384
# rep 0, T_train 795, pregret=0.1316
# rep 0, T_train 796, pregret=0.4187
# rep 0, T_train 797, pregret=0.3531
# rep 0, T_train 798, pregret=0.6812
# rep 0, T_train 799, pregret=0.7979
# rep 0, T_train 800, pregret=0.4064
# rep 0, T_train 801, pregret=0.6695
# rep 0, T_train 802, pregret=0.2426
# rep 0, T_train 803, pregret=0.5339
# rep 0, T_train 804, pregret=0.5803
# rep 0, T_train 805, pregret=0.5454
# rep 0, T_train 806, pregret=0.2898
# rep 0, T_train 807, pregret=0.4810
# rep 0, T_train 808, pregret=0.3005
# rep 0, T_train 809, pregret=0.2274
# rep 0, T_train 810, pregret=0.4441
# rep 0, T_train 811, pregret=0.5820
# rep 0, T_train 812, pregret=1.1241
# rep 0, T_train 813, pregret=0.2511
# rep 0, T_train 814, pregret=0.3045
# rep 0, T_train 815, pregret=0.2843
# rep 0, T_train 816, pregret=0.7036
# rep 0, T_train 817, pregret=0.2848
# rep 0, T_train 818, pregret=0.8239
# rep 0, T_train 819, pregret=0.4277
# rep 0, T_train 820, pregret=0.2987
# rep 0, T_train 821, pregret=0.6343
# rep 0, T_train 822, pregret=0.6867
# rep 0, T_train 823, pregret=0.1851
# rep 0, T_train 824, pregret=0.2651
# rep 0, T_train 825, pregret=0.5393
# rep 0, T_train 826, pregret=0.1942
# rep 0, T_train 827, pregret=0.4785
# rep 0, T_train 828, pregret=0.2698
# rep 0, T_train 829, pregret=0.2264
# rep 0, T_train 830, pregret=0.2745
# rep 0, T_train 831, pregret=0.7434
# rep 0, T_train 832, pregret=0.4323
# rep 0, T_train 833, pregret=0.5511
# rep 0, T_train 834, pregret=0.3669
# rep 0, T_train 835, pregret=0.2952
# rep 0, T_train 836, pregret=0.5923
# rep 0, T_train 837, pregret=0.5080
# rep 0, T_train 838, pregret=0.1607
# rep 0, T_train 839, pregret=0.2297
# rep 0, T_train 840, pregret=0.4471
# rep 0, T_train 841, pregret=0.2165
# rep 0, T_train 842, pregret=0.3451
# rep 0, T_train 843, pregret=0.5450
# rep 0, T_train 844, pregret=0.5135
# rep 0, T_train 845, pregret=0.6184
# rep 0, T_train 846, pregret=0.7852
# rep 0, T_train 847, pregret=0.4184
# rep 0, T_train 848, pregret=0.5293
# rep 0, T_train 849, pregret=0.2490
# rep 0, T_train 850, pregret=0.2822
# rep 0, T_train 851, pregret=0.5268
# rep 0, T_train 852, pregret=0.3982
# rep 0, T_train 853, pregret=0.7080
# rep 0, T_train 854, pregret=0.3456
# rep 0, T_train 855, pregret=0.7126
# rep 0, T_train 856, pregret=0.5749
# rep 0, T_train 857, pregret=0.1329
# rep 0, T_train 858, pregret=0.3531
# rep 0, T_train 859, pregret=0.5720
# rep 0, T_train 860, pregret=0.2419
# rep 0, T_train 861, pregret=0.0422
# rep 0, T_train 862, pregret=0.3791
# rep 0, T_train 863, pregret=0.6517
# rep 0, T_train 864, pregret=0.3613
# rep 0, T_train 865, pregret=0.3676
# rep 0, T_train 866, pregret=0.4898
# rep 0, T_train 867, pregret=0.6559
# rep 0, T_train 868, pregret=0.4035
# rep 0, T_train 869, pregret=0.5568
# rep 0, T_train 870, pregret=0.1976
# rep 0, T_train 871, pregret=0.5037
# rep 0, T_train 872, pregret=0.7976
# rep 0, T_train 873, pregret=0.7482
# rep 0, T_train 874, pregret=0.2345
# rep 0, T_train 875, pregret=0.0299
# rep 0, T_train 876, pregret=0.4139
# rep 0, T_train 877, pregret=0.2113
# rep 0, T_train 878, pregret=0.4017
# rep 0, T_train 879, pregret=0.4099
# rep 0, T_train 880, pregret=0.3063
# rep 0, T_train 881, pregret=0.5009
# rep 0, T_train 882, pregret=0.6063
# rep 0, T_train 883, pregret=0.3813
# rep 0, T_train 884, pregret=0.3356
# rep 0, T_train 885, pregret=0.5394
# rep 0, T_train 886, pregret=0.5587
# rep 0, T_train 887, pregret=0.2517
# rep 0, T_train 888, pregret=0.3601
# rep 0, T_train 889, pregret=0.4417
# rep 0, T_train 890, pregret=0.1147
# rep 0, T_train 891, pregret=0.6207
# rep 0, T_train 892, pregret=0.0623
# rep 0, T_train 893, pregret=0.6985
# rep 0, T_train 894, pregret=0.2585
# rep 0, T_train 895, pregret=0.2973
# rep 0, T_train 896, pregret=0.1298
# rep 0, T_train 897, pregret=0.4287
# rep 0, T_train 898, pregret=0.3706
# rep 0, T_train 899, pregret=0.1429
# rep 0, T_train 900, pregret=0.5917
# rep 0, T_train 901, pregret=0.3228
# rep 0, T_train 902, pregret=0.4770
# rep 0, T_train 903, pregret=0.3292
# rep 0, T_train 904, pregret=0.4686
# rep 0, T_train 905, pregret=0.3704
# rep 0, T_train 906, pregret=0.7580
# rep 0, T_train 907, pregret=0.5814
# rep 0, T_train 908, pregret=0.6104
# rep 0, T_train 909, pregret=0.5894
# rep 0, T_train 910, pregret=0.1836
# rep 0, T_train 911, pregret=0.1906
# rep 0, T_train 912, pregret=0.0824
# rep 0, T_train 913, pregret=0.8415
# rep 0, T_train 914, pregret=0.4675
# rep 0, T_train 915, pregret=0.3552
# rep 0, T_train 916, pregret=0.4054
# rep 0, T_train 917, pregret=0.4664
# rep 0, T_train 918, pregret=0.4789
# rep 0, T_train 919, pregret=0.1135
# rep 0, T_train 920, pregret=0.0494
# rep 0, T_train 921, pregret=0.4081
# rep 0, T_train 922, pregret=0.3092
# rep 0, T_train 923, pregret=0.7017
# rep 0, T_train 924, pregret=0.2780
# rep 0, T_train 925, pregret=0.9452
# rep 0, T_train 926, pregret=0.3372
# rep 0, T_train 927, pregret=0.5272
# rep 0, T_train 928, pregret=0.3604
# rep 0, T_train 929, pregret=0.6580
# rep 0, T_train 930, pregret=0.1030
# rep 0, T_train 931, pregret=0.6141
# rep 0, T_train 932, pregret=0.2377
# rep 0, T_train 933, pregret=0.3021
# rep 0, T_train 934, pregret=0.7086
# rep 0, T_train 935, pregret=0.4355
# rep 0, T_train 936, pregret=0.7346
# rep 0, T_train 937, pregret=0.3326
# rep 0, T_train 938, pregret=0.4782
# rep 0, T_train 939, pregret=0.4338
# rep 0, T_train 940, pregret=1.0111
# rep 0, T_train 941, pregret=0.4156
# rep 0, T_train 942, pregret=0.4265
# rep 0, T_train 943, pregret=0.1933
# rep 0, T_train 944, pregret=0.4675
# rep 0, T_train 945, pregret=0.2302
# rep 0, T_train 946, pregret=0.2215
# rep 0, T_train 947, pregret=0.6174
# rep 0, T_train 948, pregret=0.7264
# rep 0, T_train 949, pregret=0.3688
# rep 0, T_train 950, pregret=0.8506
# rep 0, T_train 951, pregret=0.4159
# rep 0, T_train 952, pregret=0.6578
# rep 0, T_train 953, pregret=0.8171
# rep 0, T_train 954, pregret=0.1838
# rep 0, T_train 955, pregret=0.5154
# rep 0, T_train 956, pregret=0.2916
# rep 0, T_train 957, pregret=0.5430
# rep 0, T_train 958, pregret=0.7573
# rep 0, T_train 959, pregret=0.6439
# rep 0, T_train 960, pregret=0.2017
# rep 0, T_train 961, pregret=0.4460
# rep 0, T_train 962, pregret=0.6158
# rep 0, T_train 963, pregret=0.2977
# rep 0, T_train 964, pregret=0.4163
# rep 0, T_train 965, pregret=0.2866
# rep 0, T_train 966, pregret=0.0686
# rep 0, T_train 967, pregret=0.5041
# rep 0, T_train 968, pregret=0.1072
# rep 0, T_train 969, pregret=0.5934
# rep 0, T_train 970, pregret=0.3590
# rep 0, T_train 971, pregret=0.7468
# rep 0, T_train 972, pregret=0.8365
# rep 0, T_train 973, pregret=0.4664
# rep 0, T_train 974, pregret=0.5438
# rep 0, T_train 975, pregret=0.4411
# rep 0, T_train 976, pregret=0.4996
# rep 0, T_train 977, pregret=0.4658
# rep 0, T_train 978, pregret=0.4080
# rep 0, T_train 979, pregret=0.4315
# rep 0, T_train 980, pregret=0.6490
# rep 0, T_train 981, pregret=0.1777
# rep 0, T_train 982, pregret=0.3662
# rep 0, T_train 983, pregret=0.8545
# rep 0, T_train 984, pregret=0.3560
# rep 0, T_train 985, pregret=0.3089
# rep 0, T_train 986, pregret=0.3360
# rep 0, T_train 987, pregret=0.6213
# rep 0, T_train 988, pregret=0.4703
# rep 0, T_train 989, pregret=0.4789
# rep 0, T_train 990, pregret=0.1920
# rep 0, T_train 991, pregret=0.2743
# rep 0, T_train 992, pregret=0.1146
# rep 0, T_train 993, pregret=0.9536
# rep 0, T_train 994, pregret=0.3871
# rep 0, T_train 995, pregret=0.8057
# rep 0, T_train 996, pregret=0.3036
# rep 0, T_train 997, pregret=0.1987
# rep 0, T_train 998, pregret=0.3789
# rep 0, T_train 999, pregret=0.0934
# rep 0, T_train 1000, pregret=0.4215
# rep 0, T_train 1001, pregret=0.5031
# rep 0, T_train 1002, pregret=0.5180
# rep 0, T_train 1003, pregret=0.6623
# rep 0, T_train 1004, pregret=0.3350
# rep 0, T_train 1005, pregret=0.4197
# rep 0, T_train 1006, pregret=0.3618
# rep 0, T_train 1007, pregret=0.4148
# rep 0, T_train 1008, pregret=0.5078
# rep 0, T_train 1009, pregret=0.6912
# rep 0, T_train 1010, pregret=0.1125
# rep 0, T_train 1011, pregret=0.3258
# rep 0, T_train 1012, pregret=0.3474
# rep 0, T_train 1013, pregret=0.4192
# rep 0, T_train 1014, pregret=0.3531
# rep 0, T_train 1015, pregret=0.3620
# rep 0, T_train 1016, pregret=0.6237
# rep 0, T_train 1017, pregret=0.7870
# rep 0, T_train 1018, pregret=0.5360
# rep 0, T_train 1019, pregret=0.4047
# rep 0, T_train 1020, pregret=0.6813
# rep 0, T_train 1021, pregret=0.3160
# rep 0, T_train 1022, pregret=0.6872
# rep 0, T_train 1023, pregret=0.0538
# rep 0, T_train 1024, pregret=0.6357
# rep 0, T_train 1025, pregret=0.5682
# rep 0, T_train 1026, pregret=1.0708
# rep 0, T_train 1027, pregret=0.6085
# rep 0, T_train 1028, pregret=0.4369
# rep 0, T_train 1029, pregret=0.1131
# rep 0, T_train 1030, pregret=0.4301
# rep 0, T_train 1031, pregret=0.0902
# rep 0, T_train 1032, pregret=0.5104
# rep 0, T_train 1033, pregret=0.6087
# rep 0, T_train 1034, pregret=0.6493
# rep 0, T_train 1035, pregret=0.5337
# rep 0, T_train 1036, pregret=0.3546
# rep 0, T_train 1037, pregret=0.1913
# rep 0, T_train 1038, pregret=0.5421
# rep 0, T_train 1039, pregret=0.2622
# rep 0, T_train 1040, pregret=0.9002
# rep 0, T_train 1041, pregret=0.8795
# rep 0, T_train 1042, pregret=0.4120
# rep 0, T_train 1043, pregret=0.8778
# rep 0, T_train 1044, pregret=0.6857
# rep 0, T_train 1045, pregret=0.3624
# rep 0, T_train 1046, pregret=0.1988
# rep 0, T_train 1047, pregret=0.2570
# rep 0, T_train 1048, pregret=0.5946
# rep 0, T_train 1049, pregret=0.0577
# rep 0, T_train 1050, pregret=0.5586
# rep 0, T_train 1051, pregret=0.3202
# rep 0, T_train 1052, pregret=0.1979
# rep 0, T_train 1053, pregret=0.1122
# rep 0, T_train 1054, pregret=0.6183
# rep 0, T_train 1055, pregret=0.4784
# rep 0, T_train 1056, pregret=0.3490
# rep 0, T_train 1057, pregret=0.1698
# rep 0, T_train 1058, pregret=0.2855
# rep 0, T_train 1059, pregret=0.5368
# rep 0, T_train 1060, pregret=0.2655
# rep 0, T_train 1061, pregret=0.3512
# rep 0, T_train 1062, pregret=0.4540
# rep 0, T_train 1063, pregret=0.0188
# rep 0, T_train 1064, pregret=0.4250
# rep 0, T_train 1065, pregret=0.6092
# rep 0, T_train 1066, pregret=0.4606
# rep 0, T_train 1067, pregret=0.2724
# rep 0, T_train 1068, pregret=0.3369
# rep 0, T_train 1069, pregret=0.4084
# rep 0, T_train 1070, pregret=0.3675
# rep 0, T_train 1071, pregret=0.2177
# rep 0, T_train 1072, pregret=0.6037
# rep 0, T_train 1073, pregret=0.7765
# rep 0, T_train 1074, pregret=0.8179
# rep 0, T_train 1075, pregret=0.1269
# rep 0, T_train 1076, pregret=0.2344
# rep 0, T_train 1077, pregret=0.4078
# rep 0, T_train 1078, pregret=0.2559
# rep 0, T_train 1079, pregret=0.9594
# rep 0, T_train 1080, pregret=0.6322
# rep 0, T_train 1081, pregret=0.6296
# rep 0, T_train 1082, pregret=0.9476
# rep 0, T_train 1083, pregret=0.4498
# rep 0, T_train 1084, pregret=0.3567
# rep 0, T_train 1085, pregret=0.2940
# rep 0, T_train 1086, pregret=0.3736
# rep 0, T_train 1087, pregret=0.1402
# rep 0, T_train 1088, pregret=0.4651
# rep 0, T_train 1089, pregret=0.2585
# rep 0, T_train 1090, pregret=0.2087
# rep 0, T_train 1091, pregret=0.8060
# rep 0, T_train 1092, pregret=0.2620
# rep 0, T_train 1093, pregret=0.0777
# rep 0, T_train 1094, pregret=0.6518
# rep 0, T_train 1095, pregret=0.6559
# rep 0, T_train 1096, pregret=0.5018
# rep 0, T_train 1097, pregret=0.4026
# rep 0, T_train 1098, pregret=0.1199
# rep 0, T_train 1099, pregret=0.3786
# rep 0, T_train 1100, pregret=0.3433
# rep 0, T_train 1101, pregret=0.2436
# rep 0, T_train 1102, pregret=0.5138
# rep 0, T_train 1103, pregret=0.5286
# rep 0, T_train 1104, pregret=0.2791
# rep 0, T_train 1105, pregret=0.1836
# rep 0, T_train 1106, pregret=0.3284
# rep 0, T_train 1107, pregret=0.7318
# rep 0, T_train 1108, pregret=1.3638
# rep 0, T_train 1109, pregret=0.3617
# rep 0, T_train 1110, pregret=0.2009
# rep 0, T_train 1111, pregret=0.8299
# rep 0, T_train 1112, pregret=0.2687
# rep 0, T_train 1113, pregret=0.4108
# rep 0, T_train 1114, pregret=0.7057
# rep 0, T_train 1115, pregret=0.4749
# rep 0, T_train 1116, pregret=0.2402
# rep 0, T_train 1117, pregret=0.2950
# rep 0, T_train 1118, pregret=0.4945
# rep 0, T_train 1119, pregret=0.1459
# rep 0, T_train 1120, pregret=0.8379
# rep 0, T_train 1121, pregret=0.7026
# rep 0, T_train 1122, pregret=0.7715
# rep 0, T_train 1123, pregret=0.4982
# rep 0, T_train 1124, pregret=0.5229
# rep 0, T_train 1125, pregret=0.1750
# rep 0, T_train 1126, pregret=0.2357
# rep 0, T_train 1127, pregret=0.5545
# rep 0, T_train 1128, pregret=0.2476
# rep 0, T_train 1129, pregret=0.4679
# rep 0, T_train 1130, pregret=0.1878
# rep 0, T_train 1131, pregret=0.8798
# rep 0, T_train 1132, pregret=0.1760
# rep 0, T_train 1133, pregret=0.5493
# rep 0, T_train 1134, pregret=0.6949
# rep 0, T_train 1135, pregret=0.6064
# rep 0, T_train 1136, pregret=0.5056
# rep 0, T_train 1137, pregret=0.6684
# rep 0, T_train 1138, pregret=0.3993
# rep 0, T_train 1139, pregret=0.5498
# rep 0, T_train 1140, pregret=0.2803
# rep 0, T_train 1141, pregret=0.6438
# rep 0, T_train 1142, pregret=0.8434
# rep 0, T_train 1143, pregret=0.4253
# rep 0, T_train 1144, pregret=0.2838
# rep 0, T_train 1145, pregret=0.3996
# rep 0, T_train 1146, pregret=0.5825
# rep 0, T_train 1147, pregret=0.4287
# rep 0, T_train 1148, pregret=0.4722
# rep 0, T_train 1149, pregret=0.6631
# rep 0, T_train 1150, pregret=0.5995
# rep 0, T_train 1151, pregret=0.3157
# rep 0, T_train 1152, pregret=0.0308
# rep 0, T_train 1153, pregret=0.3760
# rep 0, T_train 1154, pregret=0.8133
# rep 0, T_train 1155, pregret=0.2917
# rep 0, T_train 1156, pregret=0.2348
# rep 0, T_train 1157, pregret=0.5360
# rep 0, T_train 1158, pregret=1.1012
# rep 0, T_train 1159, pregret=0.3286
# rep 0, T_train 1160, pregret=0.4848
# rep 0, T_train 1161, pregret=0.4404
# rep 0, T_train 1162, pregret=0.5386
# rep 0, T_train 1163, pregret=0.3732
# rep 0, T_train 1164, pregret=0.6375
# rep 0, T_train 1165, pregret=0.7286
# rep 0, T_train 1166, pregret=0.3710
# rep 0, T_train 1167, pregret=0.4365
# rep 0, T_train 1168, pregret=0.2797
# rep 0, T_train 1169, pregret=0.7511
# rep 0, T_train 1170, pregret=0.5818
# rep 0, T_train 1171, pregret=0.2716
# rep 0, T_train 1172, pregret=0.7979
# rep 0, T_train 1173, pregret=0.3315
# rep 0, T_train 1174, pregret=0.6276
# rep 0, T_train 1175, pregret=0.5631
# rep 0, T_train 1176, pregret=0.3104
# rep 0, T_train 1177, pregret=0.3965
# rep 0, T_train 1178, pregret=0.5962
# rep 0, T_train 1179, pregret=0.2914
# rep 0, T_train 1180, pregret=0.3732
# rep 0, T_train 1181, pregret=0.5489
# rep 0, T_train 1182, pregret=0.5831
# rep 0, T_train 1183, pregret=0.5748
# rep 0, T_train 1184, pregret=0.6810
# rep 0, T_train 1185, pregret=0.3766
# rep 0, T_train 1186, pregret=0.3504
# rep 0, T_train 1187, pregret=0.1287
# rep 0, T_train 1188, pregret=0.7965
# rep 0, T_train 1189, pregret=0.1713
# rep 0, T_train 1190, pregret=0.6666
# rep 0, T_train 1191, pregret=0.7890
# rep 0, T_train 1192, pregret=0.7293
# rep 0, T_train 1193, pregret=0.8740
# rep 0, T_train 1194, pregret=0.3451
# rep 0, T_train 1195, pregret=0.5386
# rep 0, T_train 1196, pregret=0.6187
# rep 0, T_train 1197, pregret=0.5245
# rep 0, T_train 1198, pregret=0.2981
# rep 0, T_train 1199, pregret=0.4147
# rep 0, T_train 1200, pregret=0.3695
# (200,)
# rep 1, T_train 201, pregret=0.9779
# rep 1, T_train 202, pregret=0.8395
# rep 1, T_train 203, pregret=1.0709
# rep 1, T_train 204, pregret=0.9901
# rep 1, T_train 205, pregret=0.9467
# rep 1, T_train 206, pregret=0.8282
# rep 1, T_train 207, pregret=0.8694
# rep 1, T_train 208, pregret=0.7204
# rep 1, T_train 209, pregret=0.9601
# rep 1, T_train 210, pregret=1.2578
# rep 1, T_train 211, pregret=0.5457
# rep 1, T_train 212, pregret=0.5903
# rep 1, T_train 213, pregret=0.9289
# rep 1, T_train 214, pregret=0.5738
# rep 1, T_train 215, pregret=0.5278
# rep 1, T_train 216, pregret=0.6026
# rep 1, T_train 217, pregret=0.3659
# rep 1, T_train 218, pregret=0.8993
# rep 1, T_train 219, pregret=0.7487
# rep 1, T_train 220, pregret=0.9142
# rep 1, T_train 221, pregret=0.7171
# rep 1, T_train 222, pregret=0.1852
# rep 1, T_train 223, pregret=0.6947
# rep 1, T_train 224, pregret=0.5825
# rep 1, T_train 225, pregret=0.4768
# rep 1, T_train 226, pregret=0.6331
# rep 1, T_train 227, pregret=0.6270
# rep 1, T_train 228, pregret=0.2032
# rep 1, T_train 229, pregret=0.6315
# rep 1, T_train 230, pregret=0.3149
# rep 1, T_train 231, pregret=0.6455
# rep 1, T_train 232, pregret=0.5110
# rep 1, T_train 233, pregret=0.4969
# rep 1, T_train 234, pregret=0.4292
# rep 1, T_train 235, pregret=0.4914
# rep 1, T_train 236, pregret=0.5610
# rep 1, T_train 237, pregret=0.3938
# rep 1, T_train 238, pregret=0.3884
# rep 1, T_train 239, pregret=0.2035
# rep 1, T_train 240, pregret=0.2994
# rep 1, T_train 241, pregret=0.0345
# rep 1, T_train 242, pregret=0.2514
# rep 1, T_train 243, pregret=0.5352
# rep 1, T_train 244, pregret=0.6686
# rep 1, T_train 245, pregret=0.2909
# rep 1, T_train 246, pregret=0.5697
# rep 1, T_train 247, pregret=0.0506
# rep 1, T_train 248, pregret=0.8680
# rep 1, T_train 249, pregret=0.5143
# rep 1, T_train 250, pregret=0.9268
# rep 1, T_train 251, pregret=0.5219
# rep 1, T_train 252, pregret=0.3520
# rep 1, T_train 253, pregret=0.6308
# rep 1, T_train 254, pregret=0.8854
# rep 1, T_train 255, pregret=0.3063
# rep 1, T_train 256, pregret=0.2058
# rep 1, T_train 257, pregret=0.4632
# rep 1, T_train 258, pregret=0.2324
# rep 1, T_train 259, pregret=0.3615
# rep 1, T_train 260, pregret=0.4686
# rep 1, T_train 261, pregret=0.3591
# rep 1, T_train 262, pregret=0.8636
# rep 1, T_train 263, pregret=0.4666
# rep 1, T_train 264, pregret=0.8016
# rep 1, T_train 265, pregret=0.3944
# rep 1, T_train 266, pregret=0.1099
# rep 1, T_train 267, pregret=0.3415
# rep 1, T_train 268, pregret=0.3923
# rep 1, T_train 269, pregret=0.3475
# rep 1, T_train 270, pregret=0.1572
# rep 1, T_train 271, pregret=0.4300
# rep 1, T_train 272, pregret=0.6621
# rep 1, T_train 273, pregret=0.2881
# rep 1, T_train 274, pregret=0.2924
# rep 1, T_train 275, pregret=0.3821
# rep 1, T_train 276, pregret=0.3993
# rep 1, T_train 277, pregret=0.3531
# rep 1, T_train 278, pregret=0.1804
# rep 1, T_train 279, pregret=0.2145
# rep 1, T_train 280, pregret=0.5671
# rep 1, T_train 281, pregret=0.2411
# rep 1, T_train 282, pregret=0.1250
# rep 1, T_train 283, pregret=0.2894
# rep 1, T_train 284, pregret=0.5157
# rep 1, T_train 285, pregret=0.4574
# rep 1, T_train 286, pregret=0.2467
# rep 1, T_train 287, pregret=0.4309
# rep 1, T_train 288, pregret=0.3761
# rep 1, T_train 289, pregret=0.1701
# rep 1, T_train 290, pregret=0.7652
# rep 1, T_train 291, pregret=0.5394
# rep 1, T_train 292, pregret=0.4865
# rep 1, T_train 293, pregret=0.5134
# rep 1, T_train 294, pregret=0.4618
# rep 1, T_train 295, pregret=0.3224
# rep 1, T_train 296, pregret=0.4218
# rep 1, T_train 297, pregret=0.2614
# rep 1, T_train 298, pregret=0.4513
# rep 1, T_train 299, pregret=0.2096
# rep 1, T_train 300, pregret=0.3080
# rep 1, T_train 301, pregret=0.3875
# rep 1, T_train 302, pregret=0.1608
# rep 1, T_train 303, pregret=0.8659
# rep 1, T_train 304, pregret=0.8576
# rep 1, T_train 305, pregret=0.2919
# rep 1, T_train 306, pregret=0.3135
# rep 1, T_train 307, pregret=0.5584
# rep 1, T_train 308, pregret=0.8314
# rep 1, T_train 309, pregret=0.0000
# rep 1, T_train 310, pregret=0.3993
# rep 1, T_train 311, pregret=0.4552
# rep 1, T_train 312, pregret=0.6769
# rep 1, T_train 313, pregret=0.2877
# rep 1, T_train 314, pregret=0.3827
# rep 1, T_train 315, pregret=0.1642
# rep 1, T_train 316, pregret=0.0608
# rep 1, T_train 317, pregret=0.3481
# rep 1, T_train 318, pregret=0.6125
# rep 1, T_train 319, pregret=0.2040
# rep 1, T_train 320, pregret=0.5419
# rep 1, T_train 321, pregret=0.6836
# rep 1, T_train 322, pregret=0.7501
# rep 1, T_train 323, pregret=0.8543
# rep 1, T_train 324, pregret=0.1963
# rep 1, T_train 325, pregret=0.3011
# rep 1, T_train 326, pregret=0.2719
# rep 1, T_train 327, pregret=0.5915
# rep 1, T_train 328, pregret=0.2833
# rep 1, T_train 329, pregret=0.2125
# rep 1, T_train 330, pregret=0.5152
# rep 1, T_train 331, pregret=0.6225
# rep 1, T_train 332, pregret=0.6993
# rep 1, T_train 333, pregret=0.1971
# rep 1, T_train 334, pregret=0.8278
# rep 1, T_train 335, pregret=0.3428
# rep 1, T_train 336, pregret=0.7176
# rep 1, T_train 337, pregret=0.5109
# rep 1, T_train 338, pregret=0.2757
# rep 1, T_train 339, pregret=0.4023
# rep 1, T_train 340, pregret=0.4887
# rep 1, T_train 341, pregret=0.6968
# rep 1, T_train 342, pregret=0.1928
# rep 1, T_train 343, pregret=0.4348
# rep 1, T_train 344, pregret=0.5539
# rep 1, T_train 345, pregret=0.3271
# rep 1, T_train 346, pregret=0.1789
# rep 1, T_train 347, pregret=0.2054
# rep 1, T_train 348, pregret=0.7914
# rep 1, T_train 349, pregret=0.3221
# rep 1, T_train 350, pregret=0.4408
# rep 1, T_train 351, pregret=0.3368
# rep 1, T_train 352, pregret=0.8267
# rep 1, T_train 353, pregret=0.2602
# rep 1, T_train 354, pregret=0.5724
# rep 1, T_train 355, pregret=0.4114
# rep 1, T_train 356, pregret=0.2588
# rep 1, T_train 357, pregret=0.4468
# rep 1, T_train 358, pregret=0.2639
# rep 1, T_train 359, pregret=0.3386
# rep 1, T_train 360, pregret=0.6861
# rep 1, T_train 361, pregret=0.6287
# rep 1, T_train 362, pregret=0.6896
# rep 1, T_train 363, pregret=0.8464
# rep 1, T_train 364, pregret=0.4486
# rep 1, T_train 365, pregret=0.1585
# rep 1, T_train 366, pregret=0.7578
# rep 1, T_train 367, pregret=0.2846
# rep 1, T_train 368, pregret=0.3129
# rep 1, T_train 369, pregret=0.4656
# rep 1, T_train 370, pregret=0.5306
# rep 1, T_train 371, pregret=0.8303
# rep 1, T_train 372, pregret=0.6940
# rep 1, T_train 373, pregret=1.1080
# rep 1, T_train 374, pregret=0.3015
# rep 1, T_train 375, pregret=0.2958
# rep 1, T_train 376, pregret=0.2411
# rep 1, T_train 377, pregret=0.4369
# rep 1, T_train 378, pregret=0.3412
# rep 1, T_train 379, pregret=0.4881
# rep 1, T_train 380, pregret=0.4609
# rep 1, T_train 381, pregret=0.7266
# rep 1, T_train 382, pregret=0.3087
# rep 1, T_train 383, pregret=0.5530
# rep 1, T_train 384, pregret=0.3266
# rep 1, T_train 385, pregret=0.2719
# rep 1, T_train 386, pregret=0.4545
# rep 1, T_train 387, pregret=0.3364
# rep 1, T_train 388, pregret=0.3130
# rep 1, T_train 389, pregret=0.3021
# rep 1, T_train 390, pregret=0.6357
# rep 1, T_train 391, pregret=0.5175
# rep 1, T_train 392, pregret=0.3691
# rep 1, T_train 393, pregret=0.7374
# rep 1, T_train 394, pregret=0.4620
# rep 1, T_train 395, pregret=0.3351
# rep 1, T_train 396, pregret=0.1966
# rep 1, T_train 397, pregret=0.4258
# rep 1, T_train 398, pregret=0.3197
# rep 1, T_train 399, pregret=0.6615
# rep 1, T_train 400, pregret=0.4416
# rep 1, T_train 401, pregret=0.7137
# rep 1, T_train 402, pregret=0.4266
# rep 1, T_train 403, pregret=0.5231
# rep 1, T_train 404, pregret=0.4889
# rep 1, T_train 405, pregret=0.1625
# rep 1, T_train 406, pregret=0.3198
# rep 1, T_train 407, pregret=0.4385
# rep 1, T_train 408, pregret=0.2279
# rep 1, T_train 409, pregret=0.4251
# rep 1, T_train 410, pregret=0.6813
# rep 1, T_train 411, pregret=0.2631
# rep 1, T_train 412, pregret=0.3398
# rep 1, T_train 413, pregret=0.5170
# rep 1, T_train 414, pregret=0.6597
# rep 1, T_train 415, pregret=0.7591
# rep 1, T_train 416, pregret=0.2170
# rep 1, T_train 417, pregret=0.3082
# rep 1, T_train 418, pregret=0.0036
# rep 1, T_train 419, pregret=0.9441
# rep 1, T_train 420, pregret=0.7119
# rep 1, T_train 421, pregret=0.2528
# rep 1, T_train 422, pregret=0.4321
# rep 1, T_train 423, pregret=0.6924
# rep 1, T_train 424, pregret=0.5520
# rep 1, T_train 425, pregret=0.6529
# rep 1, T_train 426, pregret=0.4046
# rep 1, T_train 427, pregret=0.1978
# rep 1, T_train 428, pregret=0.2780
# rep 1, T_train 429, pregret=0.1077
# rep 1, T_train 430, pregret=0.2899
# rep 1, T_train 431, pregret=0.5308
# rep 1, T_train 432, pregret=0.1932
# rep 1, T_train 433, pregret=0.9772
# rep 1, T_train 434, pregret=0.7223
# rep 1, T_train 435, pregret=0.8217
# rep 1, T_train 436, pregret=0.4357
# rep 1, T_train 437, pregret=0.2295
# rep 1, T_train 438, pregret=0.3417
# rep 1, T_train 439, pregret=0.4049
# rep 1, T_train 440, pregret=0.3374
# rep 1, T_train 441, pregret=0.7683
# rep 1, T_train 442, pregret=0.1343
# rep 1, T_train 443, pregret=0.0263
# rep 1, T_train 444, pregret=0.3287
# rep 1, T_train 445, pregret=0.7585
# rep 1, T_train 446, pregret=0.3402
# rep 1, T_train 447, pregret=0.6578
# rep 1, T_train 448, pregret=0.5948
# rep 1, T_train 449, pregret=0.3629
# rep 1, T_train 450, pregret=0.3281
# rep 1, T_train 451, pregret=0.9558
# rep 1, T_train 452, pregret=0.1181
# rep 1, T_train 453, pregret=0.5616
# rep 1, T_train 454, pregret=0.5243
# rep 1, T_train 455, pregret=0.4058
# rep 1, T_train 456, pregret=0.5114
# rep 1, T_train 457, pregret=0.2696
# rep 1, T_train 458, pregret=0.0987
# rep 1, T_train 459, pregret=0.2631
# rep 1, T_train 460, pregret=0.3367
# rep 1, T_train 461, pregret=0.5156
# rep 1, T_train 462, pregret=0.3543
# rep 1, T_train 463, pregret=0.1424
# rep 1, T_train 464, pregret=0.3928
# rep 1, T_train 465, pregret=0.5966
# rep 1, T_train 466, pregret=0.2728
# rep 1, T_train 467, pregret=0.0606
# rep 1, T_train 468, pregret=0.2672
# rep 1, T_train 469, pregret=0.3482
# rep 1, T_train 470, pregret=0.3529
# rep 1, T_train 471, pregret=0.6969
# rep 1, T_train 472, pregret=0.3684
# rep 1, T_train 473, pregret=0.3416
# rep 1, T_train 474, pregret=0.6381
# rep 1, T_train 475, pregret=0.5322
# rep 1, T_train 476, pregret=0.7802
# rep 1, T_train 477, pregret=0.2765
# rep 1, T_train 478, pregret=0.1645
# rep 1, T_train 479, pregret=0.3382
# rep 1, T_train 480, pregret=0.3831
# rep 1, T_train 481, pregret=1.3260
# rep 1, T_train 482, pregret=0.5975
# rep 1, T_train 483, pregret=0.3410
# rep 1, T_train 484, pregret=0.3803
# rep 1, T_train 485, pregret=0.3262
# rep 1, T_train 486, pregret=0.2636
# rep 1, T_train 487, pregret=0.4858
# rep 1, T_train 488, pregret=0.1923
# rep 1, T_train 489, pregret=0.2172
# rep 1, T_train 490, pregret=0.7638
# rep 1, T_train 491, pregret=0.3150
# rep 1, T_train 492, pregret=1.0161
# rep 1, T_train 493, pregret=1.0377
# rep 1, T_train 494, pregret=0.3493
# rep 1, T_train 495, pregret=0.5484
# rep 1, T_train 496, pregret=0.6854
# rep 1, T_train 497, pregret=0.5632
# rep 1, T_train 498, pregret=0.4725
# rep 1, T_train 499, pregret=0.4070
# rep 1, T_train 500, pregret=0.3426
# rep 1, T_train 501, pregret=0.3791
# rep 1, T_train 502, pregret=0.5889
# rep 1, T_train 503, pregret=0.7924
# rep 1, T_train 504, pregret=0.3740
# rep 1, T_train 505, pregret=0.4838
# rep 1, T_train 506, pregret=0.5292
# rep 1, T_train 507, pregret=0.5862
# rep 1, T_train 508, pregret=0.4293
# rep 1, T_train 509, pregret=0.4554
# rep 1, T_train 510, pregret=0.4193
# rep 1, T_train 511, pregret=0.4392
# rep 1, T_train 512, pregret=1.1292
# rep 1, T_train 513, pregret=0.2853
# rep 1, T_train 514, pregret=0.4567
# rep 1, T_train 515, pregret=0.6579
# rep 1, T_train 516, pregret=0.2033
# rep 1, T_train 517, pregret=0.3147
# rep 1, T_train 518, pregret=0.5783
# rep 1, T_train 519, pregret=0.4169
# rep 1, T_train 520, pregret=0.5045
# rep 1, T_train 521, pregret=0.9066
# rep 1, T_train 522, pregret=0.1470
# rep 1, T_train 523, pregret=0.3307
# rep 1, T_train 524, pregret=0.8416
# rep 1, T_train 525, pregret=0.2290
# rep 1, T_train 526, pregret=0.2794
# rep 1, T_train 527, pregret=0.4984
# rep 1, T_train 528, pregret=0.4924
# rep 1, T_train 529, pregret=0.3660
# rep 1, T_train 530, pregret=0.5636
# rep 1, T_train 531, pregret=0.4800
# rep 1, T_train 532, pregret=0.6691
# rep 1, T_train 533, pregret=0.9092
# rep 1, T_train 534, pregret=0.4701
# rep 1, T_train 535, pregret=0.1820
# rep 1, T_train 536, pregret=0.2536
# rep 1, T_train 537, pregret=0.5417
# rep 1, T_train 538, pregret=0.4430
# rep 1, T_train 539, pregret=0.0648
# rep 1, T_train 540, pregret=0.5282
# rep 1, T_train 541, pregret=0.6750
# rep 1, T_train 542, pregret=0.3056
# rep 1, T_train 543, pregret=0.5429
# rep 1, T_train 544, pregret=0.5752
# rep 1, T_train 545, pregret=0.4087
# rep 1, T_train 546, pregret=0.5822
# rep 1, T_train 547, pregret=0.4790
# rep 1, T_train 548, pregret=0.5150
# rep 1, T_train 549, pregret=0.1293
# rep 1, T_train 550, pregret=0.3242
# rep 1, T_train 551, pregret=0.3537
# rep 1, T_train 552, pregret=0.7435
# rep 1, T_train 553, pregret=0.4132
# rep 1, T_train 554, pregret=0.8180
# rep 1, T_train 555, pregret=0.3348
# rep 1, T_train 556, pregret=0.4153
# rep 1, T_train 557, pregret=0.3276
# rep 1, T_train 558, pregret=0.0807
# rep 1, T_train 559, pregret=0.3328
# rep 1, T_train 560, pregret=0.4653
# rep 1, T_train 561, pregret=0.6418
# rep 1, T_train 562, pregret=0.5705
# rep 1, T_train 563, pregret=0.3257
# rep 1, T_train 564, pregret=0.2753
# rep 1, T_train 565, pregret=0.4010
# ...
# rep 9, T_train 750, pregret=0.6172
# rep 9, T_train 751, pregret=0.5160
# rep 9, T_train 752, pregret=0.5214
# rep 9, T_train 753, pregret=0.1499
# rep 9, T_train 754, pregret=0.7416
# rep 9, T_train 755, pregret=0.5861
# rep 9, T_train 756, pregret=0.6853
# rep 9, T_train 757, pregret=0.4408
# rep 9, T_train 758, pregret=0.3716
# rep 9, T_train 759, pregret=0.2351
# rep 9, T_train 760, pregret=0.6036
# rep 9, T_train 761, pregret=0.3942
# rep 9, T_train 762, pregret=0.5081
# rep 9, T_train 763, pregret=0.4312
# rep 9, T_train 764, pregret=0.5954
# rep 9, T_train 765, pregret=0.2205
# rep 9, T_train 766, pregret=0.2010
# rep 9, T_train 767, pregret=0.1595
# rep 9, T_train 768, pregret=0.1683
# rep 9, T_train 769, pregret=0.2439
# rep 9, T_train 770, pregret=0.6224
# rep 9, T_train 771, pregret=0.5285
# rep 9, T_train 772, pregret=0.3763
# rep 9, T_train 773, pregret=0.4321
# rep 9, T_train 774, pregret=0.5251
# rep 9, T_train 775, pregret=0.8088
# rep 9, T_train 776, pregret=0.0743
# rep 9, T_train 777, pregret=0.5354
# rep 9, T_train 778, pregret=0.1074
# rep 9, T_train 779, pregret=0.1897
# rep 9, T_train 780, pregret=0.8907
# rep 9, T_train 781, pregret=0.1588
# rep 9, T_train 782, pregret=0.5109
# rep 9, T_train 783, pregret=0.2210
# rep 9, T_train 784, pregret=0.3504
# rep 9, T_train 785, pregret=0.4453
# rep 9, T_train 786, pregret=0.5556
# rep 9, T_train 787, pregret=0.6266
# rep 9, T_train 788, pregret=0.4266
# rep 9, T_train 789, pregret=0.3758
# rep 9, T_train 790, pregret=0.2044
# rep 9, T_train 791, pregret=0.5859
# rep 9, T_train 792, pregret=0.4145
# rep 9, T_train 793, pregret=0.4420
# rep 9, T_train 794, pregret=0.3318
# rep 9, T_train 795, pregret=0.2193
# rep 9, T_train 796, pregret=0.3587
# rep 9, T_train 797, pregret=0.3382
# rep 9, T_train 798, pregret=0.0487
# rep 9, T_train 799, pregret=0.1295
# rep 9, T_train 800, pregret=0.8660
# rep 9, T_train 801, pregret=0.6805
# rep 9, T_train 802, pregret=0.5082
# rep 9, T_train 803, pregret=0.2858
# rep 9, T_train 804, pregret=0.3231
# rep 9, T_train 805, pregret=0.4743
# rep 9, T_train 806, pregret=0.3154
# rep 9, T_train 807, pregret=0.6898
# rep 9, T_train 808, pregret=0.3531
# rep 9, T_train 809, pregret=0.3552
# rep 9, T_train 810, pregret=0.3636
# rep 9, T_train 811, pregret=0.5811
# rep 9, T_train 812, pregret=0.2917
# rep 9, T_train 813, pregret=0.6088
# rep 9, T_train 814, pregret=0.7985
# rep 9, T_train 815, pregret=0.5807
# rep 9, T_train 816, pregret=0.2086
# rep 9, T_train 817, pregret=0.3778
# rep 9, T_train 818, pregret=0.7202
# rep 9, T_train 819, pregret=0.4434
# rep 9, T_train 820, pregret=0.7239
# rep 9, T_train 821, pregret=0.3218
# rep 9, T_train 822, pregret=0.7887
# rep 9, T_train 823, pregret=0.1316
# rep 9, T_train 824, pregret=0.6166
# rep 9, T_train 825, pregret=0.1566
# rep 9, T_train 826, pregret=0.3577
# rep 9, T_train 827, pregret=0.6154
# rep 9, T_train 828, pregret=0.3612
# rep 9, T_train 829, pregret=0.4642
# rep 9, T_train 830, pregret=0.5916
# rep 9, T_train 831, pregret=0.5106
# rep 9, T_train 832, pregret=0.5243
# rep 9, T_train 833, pregret=0.4176
# rep 9, T_train 834, pregret=0.4724
# rep 9, T_train 835, pregret=0.1813
# rep 9, T_train 836, pregret=0.3252
# rep 9, T_train 837, pregret=0.2327
# rep 9, T_train 838, pregret=0.3162
# rep 9, T_train 839, pregret=0.4761
# rep 9, T_train 840, pregret=0.3507
# rep 9, T_train 841, pregret=0.6414
# rep 9, T_train 842, pregret=0.4385
# rep 9, T_train 843, pregret=0.0265
# rep 9, T_train 844, pregret=0.3212
# rep 9, T_train 845, pregret=0.3176
# rep 9, T_train 846, pregret=0.5016
# rep 9, T_train 847, pregret=0.2000
# rep 9, T_train 848, pregret=0.2399
# rep 9, T_train 849, pregret=0.3786
# rep 9, T_train 850, pregret=0.5435
# rep 9, T_train 851, pregret=0.6315
# rep 9, T_train 852, pregret=0.5715
# rep 9, T_train 853, pregret=0.3884
# rep 9, T_train 854, pregret=0.2297
# rep 9, T_train 855, pregret=0.5057
# rep 9, T_train 856, pregret=0.5123
# rep 9, T_train 857, pregret=0.4396
# rep 9, T_train 858, pregret=0.2309
# rep 9, T_train 859, pregret=0.3157
# rep 9, T_train 860, pregret=0.6601
# rep 9, T_train 861, pregret=0.3418
# rep 9, T_train 862, pregret=0.3654
# rep 9, T_train 863, pregret=0.1096
# rep 9, T_train 864, pregret=0.5178
# rep 9, T_train 865, pregret=0.5713
# rep 9, T_train 866, pregret=0.2553
# rep 9, T_train 867, pregret=0.3246
# rep 9, T_train 868, pregret=0.5779
# rep 9, T_train 869, pregret=0.2127
# rep 9, T_train 870, pregret=0.8219
# rep 9, T_train 871, pregret=0.7835
# rep 9, T_train 872, pregret=0.7218
# rep 9, T_train 873, pregret=0.5951
# rep 9, T_train 874, pregret=0.5444
# rep 9, T_train 875, pregret=0.2080
# rep 9, T_train 876, pregret=0.2087
# rep 9, T_train 877, pregret=0.4015
# rep 9, T_train 878, pregret=0.4926
# rep 9, T_train 879, pregret=0.4196
# rep 9, T_train 880, pregret=0.6849
# rep 9, T_train 881, pregret=1.0591
# rep 9, T_train 882, pregret=0.2321
# rep 9, T_train 883, pregret=0.5471
# rep 9, T_train 884, pregret=0.3954
# rep 9, T_train 885, pregret=0.7390
# rep 9, T_train 886, pregret=0.4153
# rep 9, T_train 887, pregret=0.5030
# rep 9, T_train 888, pregret=0.4054
# rep 9, T_train 889, pregret=0.9911
# rep 9, T_train 890, pregret=0.6982
# rep 9, T_train 891, pregret=0.5853
# rep 9, T_train 892, pregret=0.5676
# rep 9, T_train 893, pregret=0.3419
# rep 9, T_train 894, pregret=0.4379
# rep 9, T_train 895, pregret=0.2995
# rep 9, T_train 896, pregret=0.1228
# rep 9, T_train 897, pregret=0.2845
# rep 9, T_train 898, pregret=0.5586
# rep 9, T_train 899, pregret=0.9182
# rep 9, T_train 900, pregret=0.7463
# rep 9, T_train 901, pregret=0.4730
# rep 9, T_train 902, pregret=0.4994
# rep 9, T_train 903, pregret=0.7231
# rep 9, T_train 904, pregret=0.3656
# rep 9, T_train 905, pregret=0.0361
# rep 9, T_train 906, pregret=0.5945
# rep 9, T_train 907, pregret=0.4647
# rep 9, T_train 908, pregret=0.6599
# rep 9, T_train 909, pregret=0.1047
# rep 9, T_train 910, pregret=0.1507
# rep 9, T_train 911, pregret=0.3964
# rep 9, T_train 912, pregret=0.4340
# rep 9, T_train 913, pregret=0.5785
# rep 9, T_train 914, pregret=0.4587
# rep 9, T_train 915, pregret=0.5776
# rep 9, T_train 916, pregret=0.3591
# rep 9, T_train 917, pregret=0.4079
# rep 9, T_train 918, pregret=0.1757
# rep 9, T_train 919, pregret=0.5528
# rep 9, T_train 920, pregret=0.2850
# rep 9, T_train 921, pregret=1.2698
# rep 9, T_train 922, pregret=0.3255
# rep 9, T_train 923, pregret=0.3183
# rep 9, T_train 924, pregret=0.2944
# rep 9, T_train 925, pregret=0.0775
# rep 9, T_train 926, pregret=0.7781
# rep 9, T_train 927, pregret=0.3730
# rep 9, T_train 928, pregret=0.5346
# rep 9, T_train 929, pregret=0.6906
# rep 9, T_train 930, pregret=0.3200
# rep 9, T_train 931, pregret=0.6387
# rep 9, T_train 932, pregret=0.9494
# rep 9, T_train 933, pregret=0.4373
# rep 9, T_train 934, pregret=0.1694
# rep 9, T_train 935, pregret=0.6613
# rep 9, T_train 936, pregret=0.1921
# rep 9, T_train 937, pregret=0.0591
# rep 9, T_train 938, pregret=0.4668
# rep 9, T_train 939, pregret=0.1582
# rep 9, T_train 940, pregret=0.5598
# rep 9, T_train 941, pregret=0.2429
# rep 9, T_train 942, pregret=0.2417
# rep 9, T_train 943, pregret=0.3935
# rep 9, T_train 944, pregret=0.6051
# rep 9, T_train 945, pregret=0.5432
# rep 9, T_train 946, pregret=0.5910
# rep 9, T_train 947, pregret=0.1900
# rep 9, T_train 948, pregret=0.4276
# rep 9, T_train 949, pregret=0.2089
# rep 9, T_train 950, pregret=0.3134
# rep 9, T_train 951, pregret=0.1507
# rep 9, T_train 952, pregret=0.1645
# rep 9, T_train 953, pregret=0.8731
# rep 9, T_train 954, pregret=0.6357
# rep 9, T_train 955, pregret=0.3231
# rep 9, T_train 956, pregret=0.4369
# rep 9, T_train 957, pregret=0.3456
# rep 9, T_train 958, pregret=0.4901
# rep 9, T_train 959, pregret=0.6440
# rep 9, T_train 960, pregret=0.5713
# rep 9, T_train 961, pregret=0.3868
# rep 9, T_train 962, pregret=0.4793
# rep 9, T_train 963, pregret=0.4784
# rep 9, T_train 964, pregret=0.3115
# rep 9, T_train 965, pregret=0.6233
# rep 9, T_train 966, pregret=0.5500
# rep 9, T_train 967, pregret=0.2786
# rep 9, T_train 968, pregret=0.5713
# rep 9, T_train 969, pregret=0.1967
# rep 9, T_train 970, pregret=0.6252
# rep 9, T_train 971, pregret=0.0216
# rep 9, T_train 972, pregret=0.5595
# rep 9, T_train 973, pregret=0.5161
# rep 9, T_train 974, pregret=0.0295
# rep 9, T_train 975, pregret=0.2277
# rep 9, T_train 976, pregret=0.2584
# rep 9, T_train 977, pregret=0.4164
# rep 9, T_train 978, pregret=0.3721
# rep 9, T_train 979, pregret=0.3210
# rep 9, T_train 980, pregret=0.8311
# rep 9, T_train 981, pregret=0.3793
# rep 9, T_train 982, pregret=0.7533
# rep 9, T_train 983, pregret=0.2607
# rep 9, T_train 984, pregret=0.5413
# rep 9, T_train 985, pregret=0.7284
# rep 9, T_train 986, pregret=0.3959
# rep 9, T_train 987, pregret=0.4529
# rep 9, T_train 988, pregret=0.3240
# rep 9, T_train 989, pregret=0.1571
# rep 9, T_train 990, pregret=0.2767
# rep 9, T_train 991, pregret=0.5407
# rep 9, T_train 992, pregret=0.5834
# rep 9, T_train 993, pregret=0.5293
# rep 9, T_train 994, pregret=0.4903
# rep 9, T_train 995, pregret=0.2765
# rep 9, T_train 996, pregret=0.5344
# rep 9, T_train 997, pregret=0.0498
# rep 9, T_train 998, pregret=0.3832
# rep 9, T_train 999, pregret=0.1377
# rep 9, T_train 1000, pregret=0.3785
# rep 9, T_train 1001, pregret=0.1984
# rep 9, T_train 1002, pregret=0.5443
# rep 9, T_train 1003, pregret=0.9584
# rep 9, T_train 1004, pregret=0.4586
# rep 9, T_train 1005, pregret=0.3026
# rep 9, T_train 1006, pregret=0.6898
# rep 9, T_train 1007, pregret=0.6714
# rep 9, T_train 1008, pregret=1.3265
# rep 9, T_train 1009, pregret=0.4445
# rep 9, T_train 1010, pregret=0.3204
# rep 9, T_train 1011, pregret=0.5940
# rep 9, T_train 1012, pregret=0.1842
# rep 9, T_train 1013, pregret=0.2680
# rep 9, T_train 1014, pregret=0.2488
# rep 9, T_train 1015, pregret=0.4382
# rep 9, T_train 1016, pregret=0.8745
# rep 9, T_train 1017, pregret=0.2712
# rep 9, T_train 1018, pregret=0.5605
# rep 9, T_train 1019, pregret=0.7712
# rep 9, T_train 1020, pregret=0.3304
# rep 9, T_train 1021, pregret=0.0277
# rep 9, T_train 1022, pregret=0.5389
# rep 9, T_train 1023, pregret=0.3940
# rep 9, T_train 1024, pregret=0.6568
# rep 9, T_train 1025, pregret=0.6899
# rep 9, T_train 1026, pregret=0.2842
# rep 9, T_train 1027, pregret=0.6521
# rep 9, T_train 1028, pregret=0.0591
# rep 9, T_train 1029, pregret=0.2317
# rep 9, T_train 1030, pregret=0.2982
# rep 9, T_train 1031, pregret=0.3530
# rep 9, T_train 1032, pregret=0.6929
# rep 9, T_train 1033, pregret=0.6569
# rep 9, T_train 1034, pregret=0.9005
# rep 9, T_train 1035, pregret=0.9592
# rep 9, T_train 1036, pregret=0.6618
# rep 9, T_train 1037, pregret=0.6687
# rep 9, T_train 1038, pregret=0.1592
# rep 9, T_train 1039, pregret=0.5572
# rep 9, T_train 1040, pregret=0.2215
# rep 9, T_train 1041, pregret=0.5735
# rep 9, T_train 1042, pregret=0.1478
# rep 9, T_train 1043, pregret=0.0900
# rep 9, T_train 1044, pregret=0.6071
# rep 9, T_train 1045, pregret=0.8721
# rep 9, T_train 1046, pregret=0.1747
# rep 9, T_train 1047, pregret=0.3377
# rep 9, T_train 1048, pregret=0.8049
# rep 9, T_train 1049, pregret=0.4465
# rep 9, T_train 1050, pregret=0.0579
# rep 9, T_train 1051, pregret=0.0850
# rep 9, T_train 1052, pregret=0.8777
# rep 9, T_train 1053, pregret=0.6935
# rep 9, T_train 1054, pregret=0.3351
# rep 9, T_train 1055, pregret=0.3616
# rep 9, T_train 1056, pregret=0.3323
# rep 9, T_train 1057, pregret=0.1765
# rep 9, T_train 1058, pregret=0.2145
# rep 9, T_train 1059, pregret=0.5412
# rep 9, T_train 1060, pregret=0.4057
# rep 9, T_train 1061, pregret=1.0461
# rep 9, T_train 1062, pregret=0.1890
# rep 9, T_train 1063, pregret=0.5918
# rep 9, T_train 1064, pregret=0.4439
# rep 9, T_train 1065, pregret=0.7666
# rep 9, T_train 1066, pregret=0.4462
# rep 9, T_train 1067, pregret=0.4786
# rep 9, T_train 1068, pregret=0.3527
# rep 9, T_train 1069, pregret=1.0945
# rep 9, T_train 1070, pregret=0.5639
# rep 9, T_train 1071, pregret=0.7033
# rep 9, T_train 1072, pregret=0.7357
# rep 9, T_train 1073, pregret=0.4941
# rep 9, T_train 1074, pregret=0.3576
# rep 9, T_train 1075, pregret=0.1827
# rep 9, T_train 1076, pregret=0.8143
# rep 9, T_train 1077, pregret=0.2366
# rep 9, T_train 1078, pregret=0.4296
# rep 9, T_train 1079, pregret=0.2629
# rep 9, T_train 1080, pregret=0.0730
# rep 9, T_train 1081, pregret=0.6857
# rep 9, T_train 1082, pregret=0.5808
# rep 9, T_train 1083, pregret=0.3152
# rep 9, T_train 1084, pregret=0.2179
# rep 9, T_train 1085, pregret=0.7563
# rep 9, T_train 1086, pregret=0.3233
# rep 9, T_train 1087, pregret=0.9166
# rep 9, T_train 1088, pregret=0.9802
# rep 9, T_train 1089, pregret=1.0253
# rep 9, T_train 1090, pregret=0.2743
# rep 9, T_train 1091, pregret=0.0703
# rep 9, T_train 1092, pregret=0.1022
# rep 9, T_train 1093, pregret=0.5984
# rep 9, T_train 1094, pregret=0.2102
# rep 9, T_train 1095, pregret=0.2133
# rep 9, T_train 1096, pregret=0.6246
# rep 9, T_train 1097, pregret=0.5313
# rep 9, T_train 1098, pregret=0.4310
# rep 9, T_train 1099, pregret=0.3624
# rep 9, T_train 1100, pregret=0.1988
# rep 9, T_train 1101, pregret=0.2592
# rep 9, T_train 1102, pregret=0.5583
# rep 9, T_train 1103, pregret=0.0882
# rep 9, T_train 1104, pregret=0.5136
# rep 9, T_train 1105, pregret=0.6441
# rep 9, T_train 1106, pregret=0.2932
# rep 9, T_train 1107, pregret=0.8632
# rep 9, T_train 1108, pregret=0.7876
# rep 9, T_train 1109, pregret=0.9944
# rep 9, T_train 1110, pregret=0.5144
# rep 9, T_train 1111, pregret=0.6615
# rep 9, T_train 1112, pregret=0.5386
# rep 9, T_train 1113, pregret=0.8993
# rep 9, T_train 1114, pregret=0.1950
# rep 9, T_train 1115, pregret=0.8892
# rep 9, T_train 1116, pregret=0.6765
# rep 9, T_train 1117, pregret=0.3866
# rep 9, T_train 1118, pregret=0.6247
# rep 9, T_train 1119, pregret=0.5914
# rep 9, T_train 1120, pregret=0.7389
# rep 9, T_train 1121, pregret=0.1756
# rep 9, T_train 1122, pregret=0.6098
# rep 9, T_train 1123, pregret=0.3456
# rep 9, T_train 1124, pregret=0.8461
# rep 9, T_train 1125, pregret=0.1513
# rep 9, T_train 1126, pregret=0.3225
# rep 9, T_train 1127, pregret=0.6325
# rep 9, T_train 1128, pregret=0.7670
# rep 9, T_train 1129, pregret=0.3138
# rep 9, T_train 1130, pregret=0.2388
# rep 9, T_train 1131, pregret=0.8627
# rep 9, T_train 1132, pregret=0.3458
# rep 9, T_train 1133, pregret=0.4067
# rep 9, T_train 1134, pregret=0.3010
# rep 9, T_train 1135, pregret=0.5221
# rep 9, T_train 1136, pregret=0.3502
# rep 9, T_train 1137, pregret=0.6013
# rep 9, T_train 1138, pregret=0.6076
# rep 9, T_train 1139, pregret=0.1580
# rep 9, T_train 1140, pregret=0.7125
# rep 9, T_train 1141, pregret=0.5044
# rep 9, T_train 1142, pregret=1.0546
# rep 9, T_train 1143, pregret=0.6648
# rep 9, T_train 1144, pregret=0.4432
# rep 9, T_train 1145, pregret=0.4997
# rep 9, T_train 1146, pregret=0.4273
# rep 9, T_train 1147, pregret=0.1022
# rep 9, T_train 1148, pregret=0.2881
# rep 9, T_train 1149, pregret=0.4149
# rep 9, T_train 1150, pregret=0.3000
# rep 9, T_train 1151, pregret=0.6410
# rep 9, T_train 1152, pregret=0.7544
# rep 9, T_train 1153, pregret=0.7347
# rep 9, T_train 1154, pregret=0.8849
# rep 9, T_train 1155, pregret=0.2607
# rep 9, T_train 1156, pregret=0.1383
# rep 9, T_train 1157, pregret=1.0199
# rep 9, T_train 1158, pregret=0.6885
# rep 9, T_train 1159, pregret=0.2408
# rep 9, T_train 1160, pregret=0.6042
# rep 9, T_train 1161, pregret=1.0584
# rep 9, T_train 1162, pregret=0.2975
# rep 9, T_train 1163, pregret=0.3413
# rep 9, T_train 1164, pregret=0.2808
# rep 9, T_train 1165, pregret=0.4397
# rep 9, T_train 1166, pregret=0.6487
# rep 9, T_train 1167, pregret=0.3513
# rep 9, T_train 1168, pregret=0.5598
# rep 9, T_train 1169, pregret=0.2674
# rep 9, T_train 1170, pregret=0.4006
# rep 9, T_train 1171, pregret=0.5544
# rep 9, T_train 1172, pregret=0.5390
# rep 9, T_train 1173, pregret=0.3647
# rep 9, T_train 1174, pregret=0.6594
# rep 9, T_train 1175, pregret=0.4883
# rep 9, T_train 1176, pregret=0.6083
# rep 9, T_train 1177, pregret=0.8151
# rep 9, T_train 1178, pregret=0.2756
# rep 9, T_train 1179, pregret=0.0237
# rep 9, T_train 1180, pregret=0.6882
# rep 9, T_train 1181, pregret=0.4137
# rep 9, T_train 1182, pregret=0.2087
# rep 9, T_train 1183, pregret=0.3469
# rep 9, T_train 1184, pregret=0.3693
# rep 9, T_train 1185, pregret=0.0647
# rep 9, T_train 1186, pregret=0.6520
# rep 9, T_train 1187, pregret=0.4018
# rep 9, T_train 1188, pregret=0.3477
# rep 9, T_train 1189, pregret=0.5983
# rep 9, T_train 1190, pregret=0.2844
# rep 9, T_train 1191, pregret=0.2622
# rep 9, T_train 1192, pregret=0.2854
# rep 9, T_train 1193, pregret=0.4274
# rep 9, T_train 1194, pregret=0.2608
# rep 9, T_train 1195, pregret=0.5155
# rep 9, T_train 1196, pregret=0.3618
# rep 9, T_train 1197, pregret=0.3687
# rep 9, T_train 1198, pregret=0.5397
# rep 9, T_train 1199, pregret=0.3565
# rep 9, T_train 1200, pregret=0.0604

# %%
T = 200
gamma = 0.9
t_prime_action = 6
t_prime_value = 0
threshold = 1e-4
DELTA_T = 1000
PREGRETS_random = []
epsilon = 0.1
for rep in range(10):
    # one simulation per rep
    actions, states, irewards, times = simulate_data_raw(
        rewards_in_period=rewards_in_period,
        session_duration=2000,
        tdim=50, n_sessions=1, seed=515+rep
    )
    prewards = make_weighted_target(irewards, gamma,T = T,normalization = False)

    # initial dataset
    X_train = np.hstack([position_encoder(states[:T,0], type="onehot"), states[:T,1:]])
    Y_train_action = irewards[:T]
    rf_action = train_model(X_train, Y_train_action, None)

    Y_train_value = prewards

    rf_value = train_model(X_train, Y_train_value)
    print(Y_train_value.shape)
    
    PREGRET = []
    current_state = states[T,0]
    for delta_t in range(1,DELTA_T+1):
        next_state, df_paths, preds = choose_next_state(rf_action,rf_value, current_state, T+delta_t, t_prime_action, t_prime_value, gamma)
        if np.random.rand() < epsilon:
            candidates = get_candidates(current_state, T+delta_t)
            next_state = np.random.choice(candidates)

        next_time = T+1+delta_t
        next_features = np.hstack([
            position_encoder(np.array([next_state]), type="onehot"),
            time_embedding_np(next_time, tdim=50).reshape(1,-1)
        ])
        next_reward = reward_simulate(next_state, next_time-1, rewards_in_period)

        ## PolicyIteration

        X_train = np.hstack([position_encoder(states[:T+delta_t,0], type="onehot"), states[:T+delta_t,1:]])
        Y_train_action = irewards[:T+delta_t]

        rf_action = train_model(X_train, Y_train_action, rf_action)

        Y_train_value = make_weighted_target(Y_train_action, gamma,T = T+delta_t,normalization = False)
        is_pos = (Y_train_value > threshold).astype(int)
        pos = is_pos.sum()
        neg = len(Y_train_value) - pos
        w = np.where(Y_train_value > threshold, (neg / max(pos,1)), 1.0)
        print(X_train.shape,Y_train_value.shape,w.shape)
        rf_value = train_model(X_train, Y_train_value, sample_weight=w)
        
        current_state = next_state  # move forward

    
        T_p = delta_t + T
        start_state = current_state
        pregret_val,pred = run_inference(rf_action, rf_value, start_state, T_p,  t_prime_action, t_prime_value, gamma, rewards_in_period)
        print(f"rep {rep}, T_train {T_p}, pregret={pregret_val:.4f}")
        PREGRET.append(pregret_val)

    PREGRETS_random.append(PREGRET)
# Out:
# (200,)
# (201, 57) (201,) (201,)
# rep 0, T_train 201, pregret=0.3516
# (202, 57) (202,) (202,)
# rep 0, T_train 202, pregret=0.6014
# (203, 57) (203,) (203,)
# rep 0, T_train 203, pregret=0.3840
# (204, 57) (204,) (204,)
# rep 0, T_train 204, pregret=0.6292
# (205, 57) (205,) (205,)
# rep 0, T_train 205, pregret=0.3604
# (206, 57) (206,) (206,)
# rep 0, T_train 206, pregret=0.5990
# (207, 57) (207,) (207,)
# rep 0, T_train 207, pregret=0.4004
# (208, 57) (208,) (208,)
# rep 0, T_train 208, pregret=0.1313
# (209, 57) (209,) (209,)
# rep 0, T_train 209, pregret=0.3785
# (210, 57) (210,) (210,)
# rep 0, T_train 210, pregret=0.6124
# (211, 57) (211,) (211,)
# rep 0, T_train 211, pregret=0.1472
# (212, 57) (212,) (212,)
# rep 0, T_train 212, pregret=0.4759
# (213, 57) (213,) (213,)
# rep 0, T_train 213, pregret=0.6228
# (214, 57) (214,) (214,)
# rep 0, T_train 214, pregret=0.3392
# (215, 57) (215,) (215,)
# rep 0, T_train 215, pregret=0.3760
# (216, 57) (216,) (216,)
# rep 0, T_train 216, pregret=0.4348
# (217, 57) (217,) (217,)
# rep 0, T_train 217, pregret=0.3026
# (218, 57) (218,) (218,)
# rep 0, T_train 218, pregret=0.8080
# (219, 57) (219,) (219,)
# rep 0, T_train 219, pregret=0.2241
# (220, 57) (220,) (220,)
# rep 0, T_train 220, pregret=0.0207
# (221, 57) (221,) (221,)
# rep 0, T_train 221, pregret=0.7277
# (222, 57) (222,) (222,)
# rep 0, T_train 222, pregret=0.1493
# (223, 57) (223,) (223,)
# rep 0, T_train 223, pregret=0.7241
# (224, 57) (224,) (224,)
# rep 0, T_train 224, pregret=0.3295
# (225, 57) (225,) (225,)
# rep 0, T_train 225, pregret=0.6713
# (226, 57) (226,) (226,)
# rep 0, T_train 226, pregret=0.2252
# (227, 57) (227,) (227,)
# rep 0, T_train 227, pregret=0.6723
# (228, 57) (228,) (228,)
# rep 0, T_train 228, pregret=0.7108
# (229, 57) (229,) (229,)
# rep 0, T_train 229, pregret=0.2152
# (230, 57) (230,) (230,)
# rep 0, T_train 230, pregret=0.1292
# (231, 57) (231,) (231,)
# rep 0, T_train 231, pregret=0.3678
# (232, 57) (232,) (232,)
# rep 0, T_train 232, pregret=0.2539
# (233, 57) (233,) (233,)
# rep 0, T_train 233, pregret=0.3574
# (234, 57) (234,) (234,)
# rep 0, T_train 234, pregret=0.8263
# (235, 57) (235,) (235,)
# rep 0, T_train 235, pregret=0.6393
# (236, 57) (236,) (236,)
# rep 0, T_train 236, pregret=0.5458
# (237, 57) (237,) (237,)
# rep 0, T_train 237, pregret=0.9561
# (238, 57) (238,) (238,)
# rep 0, T_train 238, pregret=0.1533
# (239, 57) (239,) (239,)
# rep 0, T_train 239, pregret=0.4156
# (240, 57) (240,) (240,)
# rep 0, T_train 240, pregret=0.6424
# (241, 57) (241,) (241,)
# rep 0, T_train 241, pregret=0.2166
# (242, 57) (242,) (242,)
# rep 0, T_train 242, pregret=0.5788
# (243, 57) (243,) (243,)
# rep 0, T_train 243, pregret=0.4837
# (244, 57) (244,) (244,)
# rep 0, T_train 244, pregret=0.2838
# (245, 57) (245,) (245,)
# rep 0, T_train 245, pregret=0.5833
# (246, 57) (246,) (246,)
# rep 0, T_train 246, pregret=0.1850
# (247, 57) (247,) (247,)
# rep 0, T_train 247, pregret=0.4264
# (248, 57) (248,) (248,)
# rep 0, T_train 248, pregret=0.4588
# (249, 57) (249,) (249,)
# rep 0, T_train 249, pregret=0.1615
# (250, 57) (250,) (250,)
# rep 0, T_train 250, pregret=0.8307
# (251, 57) (251,) (251,)
# rep 0, T_train 251, pregret=0.0448
# (252, 57) (252,) (252,)
# rep 0, T_train 252, pregret=0.7273
# (253, 57) (253,) (253,)
# rep 0, T_train 253, pregret=0.2952
# (254, 57) (254,) (254,)
# rep 0, T_train 254, pregret=0.8953
# (255, 57) (255,) (255,)
# rep 0, T_train 255, pregret=0.9046
# (256, 57) (256,) (256,)
# rep 0, T_train 256, pregret=1.0195
# (257, 57) (257,) (257,)
# rep 0, T_train 257, pregret=0.2019
# (258, 57) (258,) (258,)
# rep 0, T_train 258, pregret=0.4323
# (259, 57) (259,) (259,)
# rep 0, T_train 259, pregret=0.4923
# (260, 57) (260,) (260,)
# rep 0, T_train 260, pregret=0.3635
# (261, 57) (261,) (261,)
# rep 0, T_train 261, pregret=0.5434
# (262, 57) (262,) (262,)
# rep 0, T_train 262, pregret=0.2172
# (263, 57) (263,) (263,)
# rep 0, T_train 263, pregret=0.2812
# (264, 57) (264,) (264,)
# rep 0, T_train 264, pregret=0.3650
# (265, 57) (265,) (265,)
# rep 0, T_train 265, pregret=0.5365
# (266, 57) (266,) (266,)
# rep 0, T_train 266, pregret=0.4045
# (267, 57) (267,) (267,)
# rep 0, T_train 267, pregret=0.2821
# (268, 57) (268,) (268,)
# rep 0, T_train 268, pregret=0.4244
# (269, 57) (269,) (269,)
# rep 0, T_train 269, pregret=0.2544
# (270, 57) (270,) (270,)
# rep 0, T_train 270, pregret=0.1337
# (271, 57) (271,) (271,)
# rep 0, T_train 271, pregret=0.4026
# (272, 57) (272,) (272,)
# rep 0, T_train 272, pregret=0.6412
# (273, 57) (273,) (273,)
# rep 0, T_train 273, pregret=0.4112
# (274, 57) (274,) (274,)
# rep 0, T_train 274, pregret=0.8291
# (275, 57) (275,) (275,)
# rep 0, T_train 275, pregret=0.2538
# (276, 57) (276,) (276,)
# rep 0, T_train 276, pregret=0.1302
# (277, 57) (277,) (277,)
# rep 0, T_train 277, pregret=0.2042
# (278, 57) (278,) (278,)
# rep 0, T_train 278, pregret=1.0739
# (279, 57) (279,) (279,)
# rep 0, T_train 279, pregret=0.3449
# (280, 57) (280,) (280,)
# rep 0, T_train 280, pregret=0.2562
# (281, 57) (281,) (281,)
# rep 0, T_train 281, pregret=0.2459
# (282, 57) (282,) (282,)
# rep 0, T_train 282, pregret=0.7819
# (283, 57) (283,) (283,)
# rep 0, T_train 283, pregret=0.4088
# (284, 57) (284,) (284,)
# rep 0, T_train 284, pregret=0.4705
# (285, 57) (285,) (285,)
# rep 0, T_train 285, pregret=0.3662
# (286, 57) (286,) (286,)
# rep 0, T_train 286, pregret=0.3338
# (287, 57) (287,) (287,)
# rep 0, T_train 287, pregret=0.3703
# (288, 57) (288,) (288,)
# rep 0, T_train 288, pregret=0.3173
# (289, 57) (289,) (289,)
# rep 0, T_train 289, pregret=0.4032
# (290, 57) (290,) (290,)
# rep 0, T_train 290, pregret=0.2624
# (291, 57) (291,) (291,)
# rep 0, T_train 291, pregret=0.5298
# (292, 57) (292,) (292,)
# rep 0, T_train 292, pregret=0.1895
# (293, 57) (293,) (293,)
# rep 0, T_train 293, pregret=0.4158
# (294, 57) (294,) (294,)
# rep 0, T_train 294, pregret=0.2719
# (295, 57) (295,) (295,)
# rep 0, T_train 295, pregret=0.3889
# (296, 57) (296,) (296,)
# rep 0, T_train 296, pregret=0.5988
# (297, 57) (297,) (297,)
# rep 0, T_train 297, pregret=0.2485
# (298, 57) (298,) (298,)
# rep 0, T_train 298, pregret=0.5402
# (299, 57) (299,) (299,)
# rep 0, T_train 299, pregret=0.2425
# (300, 57) (300,) (300,)
# rep 0, T_train 300, pregret=1.0214
# (301, 57) (301,) (301,)
# rep 0, T_train 301, pregret=0.3512
# (302, 57) (302,) (302,)
# rep 0, T_train 302, pregret=0.4714
# (303, 57) (303,) (303,)
# rep 0, T_train 303, pregret=0.5884
# (304, 57) (304,) (304,)
# rep 0, T_train 304, pregret=0.2451
# (305, 57) (305,) (305,)
# rep 0, T_train 305, pregret=0.1894
# (306, 57) (306,) (306,)
# rep 0, T_train 306, pregret=0.4042
# (307, 57) (307,) (307,)
# rep 0, T_train 307, pregret=0.8326
# (308, 57) (308,) (308,)
# rep 0, T_train 308, pregret=0.4623
# (309, 57) (309,) (309,)
# rep 0, T_train 309, pregret=0.2823
# (310, 57) (310,) (310,)
# rep 0, T_train 310, pregret=0.1725
# (311, 57) (311,) (311,)
# rep 0, T_train 311, pregret=0.2100
# (312, 57) (312,) (312,)
# rep 0, T_train 312, pregret=0.1692
# (313, 57) (313,) (313,)
# rep 0, T_train 313, pregret=0.1278
# (314, 57) (314,) (314,)
# rep 0, T_train 314, pregret=0.3047
# (315, 57) (315,) (315,)
# rep 0, T_train 315, pregret=0.2836
# (316, 57) (316,) (316,)
# rep 0, T_train 316, pregret=0.2945
# (317, 57) (317,) (317,)
# rep 0, T_train 317, pregret=0.4637
# (318, 57) (318,) (318,)
# rep 0, T_train 318, pregret=0.7234
# (319, 57) (319,) (319,)
# rep 0, T_train 319, pregret=0.3576
# (320, 57) (320,) (320,)
# rep 0, T_train 320, pregret=0.5205
# (321, 57) (321,) (321,)
# rep 0, T_train 321, pregret=1.1019
# (322, 57) (322,) (322,)
# rep 0, T_train 322, pregret=0.7191
# (323, 57) (323,) (323,)
# rep 0, T_train 323, pregret=0.3971
# (324, 57) (324,) (324,)
# rep 0, T_train 324, pregret=0.5238
# (325, 57) (325,) (325,)
# rep 0, T_train 325, pregret=0.1672
# (326, 57) (326,) (326,)
# rep 0, T_train 326, pregret=0.5235
# (327, 57) (327,) (327,)
# rep 0, T_train 327, pregret=0.6741
# (328, 57) (328,) (328,)
# rep 0, T_train 328, pregret=0.3163
# (329, 57) (329,) (329,)
# rep 0, T_train 329, pregret=0.1966
# (330, 57) (330,) (330,)
# rep 0, T_train 330, pregret=0.7064
# (331, 57) (331,) (331,)
# rep 0, T_train 331, pregret=0.3264
# (332, 57) (332,) (332,)
# rep 0, T_train 332, pregret=0.6376
# (333, 57) (333,) (333,)
# rep 0, T_train 333, pregret=0.5830
# (334, 57) (334,) (334,)
# rep 0, T_train 334, pregret=0.0901
# (335, 57) (335,) (335,)
# rep 0, T_train 335, pregret=0.8098
# (336, 57) (336,) (336,)
# rep 0, T_train 336, pregret=0.1920
# (337, 57) (337,) (337,)
# rep 0, T_train 337, pregret=0.2982
# (338, 57) (338,) (338,)
# rep 0, T_train 338, pregret=0.6939
# (339, 57) (339,) (339,)
# rep 0, T_train 339, pregret=0.3224
# (340, 57) (340,) (340,)
# rep 0, T_train 340, pregret=0.5098
# (341, 57) (341,) (341,)
# rep 0, T_train 341, pregret=0.6764
# (342, 57) (342,) (342,)
# rep 0, T_train 342, pregret=0.5884
# (343, 57) (343,) (343,)
# rep 0, T_train 343, pregret=0.7280
# (344, 57) (344,) (344,)
# rep 0, T_train 344, pregret=0.1899
# (345, 57) (345,) (345,)
# rep 0, T_train 345, pregret=0.4113
# (346, 57) (346,) (346,)
# rep 0, T_train 346, pregret=0.1310
# (347, 57) (347,) (347,)
# rep 0, T_train 347, pregret=0.4205
# (348, 57) (348,) (348,)
# rep 0, T_train 348, pregret=0.6980
# (349, 57) (349,) (349,)
# rep 0, T_train 349, pregret=0.2464
# (350, 57) (350,) (350,)
# rep 0, T_train 350, pregret=0.6566
# (351, 57) (351,) (351,)
# rep 0, T_train 351, pregret=0.2424
# (352, 57) (352,) (352,)
# rep 0, T_train 352, pregret=0.5488
# (353, 57) (353,) (353,)
# rep 0, T_train 353, pregret=0.4881
# (354, 57) (354,) (354,)
# rep 0, T_train 354, pregret=0.6290
# (355, 57) (355,) (355,)
# rep 0, T_train 355, pregret=0.3260
# (356, 57) (356,) (356,)
# rep 0, T_train 356, pregret=0.5179
# (357, 57) (357,) (357,)
# rep 0, T_train 357, pregret=0.5224
# (358, 57) (358,) (358,)
# rep 0, T_train 358, pregret=0.1022
# (359, 57) (359,) (359,)
# rep 0, T_train 359, pregret=0.3135
# (360, 57) (360,) (360,)
# rep 0, T_train 360, pregret=0.2237
# (361, 57) (361,) (361,)
# rep 0, T_train 361, pregret=0.2113
# (362, 57) (362,) (362,)
# rep 0, T_train 362, pregret=0.1773
# (363, 57) (363,) (363,)
# rep 0, T_train 363, pregret=0.1982
# (364, 57) (364,) (364,)
# rep 0, T_train 364, pregret=0.7662
# (365, 57) (365,) (365,)
# rep 0, T_train 365, pregret=0.4434
# (366, 57) (366,) (366,)
# rep 0, T_train 366, pregret=0.7112
# (367, 57) (367,) (367,)
# rep 0, T_train 367, pregret=0.2810
# (368, 57) (368,) (368,)
# rep 0, T_train 368, pregret=0.3852
# (369, 57) (369,) (369,)
# rep 0, T_train 369, pregret=0.2952
# (370, 57) (370,) (370,)
# rep 0, T_train 370, pregret=0.2155
# (371, 57) (371,) (371,)
# rep 0, T_train 371, pregret=0.3846
# (372, 57) (372,) (372,)
# rep 0, T_train 372, pregret=0.5971
# (373, 57) (373,) (373,)
# rep 0, T_train 373, pregret=0.3820
# (374, 57) (374,) (374,)
# rep 0, T_train 374, pregret=0.4934
# (375, 57) (375,) (375,)
# rep 0, T_train 375, pregret=0.0418
# (376, 57) (376,) (376,)
# rep 0, T_train 376, pregret=0.3077
# (377, 57) (377,) (377,)
# rep 0, T_train 377, pregret=0.3363
# (378, 57) (378,) (378,)
# rep 0, T_train 378, pregret=0.1131
# (379, 57) (379,) (379,)
# rep 0, T_train 379, pregret=0.4298
# (380, 57) (380,) (380,)
# rep 0, T_train 380, pregret=0.3575
# (381, 57) (381,) (381,)
# rep 0, T_train 381, pregret=0.2370
# (382, 57) (382,) (382,)
# rep 0, T_train 382, pregret=0.7165
# (383, 57) (383,) (383,)
# rep 0, T_train 383, pregret=0.3269
# (384, 57) (384,) (384,)
# rep 0, T_train 384, pregret=0.2762
# (385, 57) (385,) (385,)
# rep 0, T_train 385, pregret=0.4572
# (386, 57) (386,) (386,)
# rep 0, T_train 386, pregret=0.4612
# (387, 57) (387,) (387,)
# rep 0, T_train 387, pregret=0.2454
# (388, 57) (388,) (388,)
# rep 0, T_train 388, pregret=0.0631
# (389, 57) (389,) (389,)
# rep 0, T_train 389, pregret=0.3867
# (390, 57) (390,) (390,)
# rep 0, T_train 390, pregret=0.3490
# (391, 57) (391,) (391,)
# rep 0, T_train 391, pregret=0.4351
# (392, 57) (392,) (392,)
# rep 0, T_train 392, pregret=0.2679
# (393, 57) (393,) (393,)
# rep 0, T_train 393, pregret=0.9113
# (394, 57) (394,) (394,)
# rep 0, T_train 394, pregret=0.0724
# (395, 57) (395,) (395,)
# rep 0, T_train 395, pregret=0.1234
# (396, 57) (396,) (396,)
# rep 0, T_train 396, pregret=0.0387
# (397, 57) (397,) (397,)
# rep 0, T_train 397, pregret=0.4667
# (398, 57) (398,) (398,)
# rep 0, T_train 398, pregret=0.6458
# (399, 57) (399,) (399,)
# rep 0, T_train 399, pregret=0.5927
# (400, 57) (400,) (400,)
# rep 0, T_train 400, pregret=0.1529
# (401, 57) (401,) (401,)
# rep 0, T_train 401, pregret=0.5508
# (402, 57) (402,) (402,)
# rep 0, T_train 402, pregret=0.4817
# (403, 57) (403,) (403,)
# rep 0, T_train 403, pregret=0.3606
# (404, 57) (404,) (404,)
# rep 0, T_train 404, pregret=0.3197
# (405, 57) (405,) (405,)
# rep 0, T_train 405, pregret=0.5590
# (406, 57) (406,) (406,)
# rep 0, T_train 406, pregret=0.2504
# (407, 57) (407,) (407,)
# rep 0, T_train 407, pregret=0.2930
# (408, 57) (408,) (408,)
# rep 0, T_train 408, pregret=0.3745
# (409, 57) (409,) (409,)
# rep 0, T_train 409, pregret=0.7678
# (410, 57) (410,) (410,)
# rep 0, T_train 410, pregret=0.7475
# (411, 57) (411,) (411,)
# rep 0, T_train 411, pregret=0.2451
# (412, 57) (412,) (412,)
# rep 0, T_train 412, pregret=0.6232
# (413, 57) (413,) (413,)
# rep 0, T_train 413, pregret=0.2850
# (414, 57) (414,) (414,)
# rep 0, T_train 414, pregret=0.5450
# (415, 57) (415,) (415,)
# rep 0, T_train 415, pregret=0.4867
# (416, 57) (416,) (416,)
# rep 0, T_train 416, pregret=0.3561
# (417, 57) (417,) (417,)
# rep 0, T_train 417, pregret=0.5069
# (418, 57) (418,) (418,)
# rep 0, T_train 418, pregret=0.4283
# (419, 57) (419,) (419,)
# rep 0, T_train 419, pregret=0.0299
# (420, 57) (420,) (420,)
# rep 0, T_train 420, pregret=0.6339
# (421, 57) (421,) (421,)
# rep 0, T_train 421, pregret=0.8448
# (422, 57) (422,) (422,)
# rep 0, T_train 422, pregret=0.8559
# (423, 57) (423,) (423,)
# rep 0, T_train 423, pregret=0.3199
# (424, 57) (424,) (424,)
# rep 0, T_train 424, pregret=0.3989
# (425, 57) (425,) (425,)
# rep 0, T_train 425, pregret=0.4330
# (426, 57) (426,) (426,)
# rep 0, T_train 426, pregret=0.1560
# (427, 57) (427,) (427,)
# rep 0, T_train 427, pregret=0.4606
# (428, 57) (428,) (428,)
# rep 0, T_train 428, pregret=0.1994
# (429, 57) (429,) (429,)
# rep 0, T_train 429, pregret=0.5768
# (430, 57) (430,) (430,)
# rep 0, T_train 430, pregret=0.3727
# (431, 57) (431,) (431,)
# rep 0, T_train 431, pregret=0.2989
# (432, 57) (432,) (432,)
# rep 0, T_train 432, pregret=1.3137
# (433, 57) (433,) (433,)
# rep 0, T_train 433, pregret=0.5100
# (434, 57) (434,) (434,)
# rep 0, T_train 434, pregret=0.2176
# (435, 57) (435,) (435,)
# rep 0, T_train 435, pregret=0.2117
# (436, 57) (436,) (436,)
# rep 0, T_train 436, pregret=0.9759
# (437, 57) (437,) (437,)
# rep 0, T_train 437, pregret=0.1979
# (438, 57) (438,) (438,)
# rep 0, T_train 438, pregret=0.5264
# (439, 57) (439,) (439,)
# rep 0, T_train 439, pregret=0.3366
# (440, 57) (440,) (440,)
# rep 0, T_train 440, pregret=0.3867
# (441, 57) (441,) (441,)
# rep 0, T_train 441, pregret=0.3696
# (442, 57) (442,) (442,)
# rep 0, T_train 442, pregret=0.2009
# (443, 57) (443,) (443,)
# rep 0, T_train 443, pregret=0.4395
# (444, 57) (444,) (444,)
# rep 0, T_train 444, pregret=0.5452
# (445, 57) (445,) (445,)
# rep 0, T_train 445, pregret=0.3498
# (446, 57) (446,) (446,)
# rep 0, T_train 446, pregret=0.3806
# (447, 57) (447,) (447,)
# rep 0, T_train 447, pregret=0.8221
# (448, 57) (448,) (448,)
# rep 0, T_train 448, pregret=0.1282
# (449, 57) (449,) (449,)
# rep 0, T_train 449, pregret=0.5340
# (450, 57) (450,) (450,)
# rep 0, T_train 450, pregret=0.2481
# (451, 57) (451,) (451,)
# rep 0, T_train 451, pregret=0.1392
# (452, 57) (452,) (452,)
# rep 0, T_train 452, pregret=0.2281
# (453, 57) (453,) (453,)
# rep 0, T_train 453, pregret=0.2871
# (454, 57) (454,) (454,)
# rep 0, T_train 454, pregret=0.2773
# (455, 57) (455,) (455,)
# rep 0, T_train 455, pregret=0.4631
# (456, 57) (456,) (456,)
# rep 0, T_train 456, pregret=0.3042
# (457, 57) (457,) (457,)
# rep 0, T_train 457, pregret=0.1799
# (458, 57) (458,) (458,)
# rep 0, T_train 458, pregret=0.5838
# (459, 57) (459,) (459,)
# rep 0, T_train 459, pregret=0.5397
# (460, 57) (460,) (460,)
# rep 0, T_train 460, pregret=0.4016
# (461, 57) (461,) (461,)
# rep 0, T_train 461, pregret=0.7966
# (462, 57) (462,) (462,)
# rep 0, T_train 462, pregret=0.4882
# (463, 57) (463,) (463,)
# rep 0, T_train 463, pregret=0.2932
# (464, 57) (464,) (464,)
# rep 0, T_train 464, pregret=0.8189
# (465, 57) (465,) (465,)
# rep 0, T_train 465, pregret=0.5805
# (466, 57) (466,) (466,)
# rep 0, T_train 466, pregret=0.4377
# (467, 57) (467,) (467,)
# rep 0, T_train 467, pregret=0.4438
# (468, 57) (468,) (468,)
# rep 0, T_train 468, pregret=0.2151
# (469, 57) (469,) (469,)
# rep 0, T_train 469, pregret=0.4460
# (470, 57) (470,) (470,)
# rep 0, T_train 470, pregret=0.7489
# (471, 57) (471,) (471,)
# rep 0, T_train 471, pregret=0.9596
# (472, 57) (472,) (472,)
# rep 0, T_train 472, pregret=0.5016
# (473, 57) (473,) (473,)
# rep 0, T_train 473, pregret=0.5956
# (474, 57) (474,) (474,)
# rep 0, T_train 474, pregret=0.1547
# (475, 57) (475,) (475,)
# rep 0, T_train 475, pregret=0.6050
# (476, 57) (476,) (476,)
# rep 0, T_train 476, pregret=0.3340
# (477, 57) (477,) (477,)
# rep 0, T_train 477, pregret=0.3106
# (478, 57) (478,) (478,)
# rep 0, T_train 478, pregret=0.3301
# (479, 57) (479,) (479,)
# rep 0, T_train 479, pregret=0.4348
# (480, 57) (480,) (480,)
# rep 0, T_train 480, pregret=0.5965
# (481, 57) (481,) (481,)
# rep 0, T_train 481, pregret=0.7955
# (482, 57) (482,) (482,)
# rep 0, T_train 482, pregret=0.2391
# (483, 57) (483,) (483,)
# rep 0, T_train 483, pregret=0.5429
# (484, 57) (484,) (484,)
# rep 0, T_train 484, pregret=0.6021
# (485, 57) (485,) (485,)
# rep 0, T_train 485, pregret=0.7036
# (486, 57) (486,) (486,)
# rep 0, T_train 486, pregret=0.2302
# (487, 57) (487,) (487,)
# rep 0, T_train 487, pregret=0.3968
# (488, 57) (488,) (488,)
# rep 0, T_train 488, pregret=0.5060
# (489, 57) (489,) (489,)
# rep 0, T_train 489, pregret=0.4993
# (490, 57) (490,) (490,)
# rep 0, T_train 490, pregret=0.4793
# (491, 57) (491,) (491,)
# rep 0, T_train 491, pregret=0.6144
# (492, 57) (492,) (492,)
# rep 0, T_train 492, pregret=0.4737
# (493, 57) (493,) (493,)
# rep 0, T_train 493, pregret=0.3949
# (494, 57) (494,) (494,)
# rep 0, T_train 494, pregret=0.1818
# (495, 57) (495,) (495,)
# rep 0, T_train 495, pregret=0.5293
# (496, 57) (496,) (496,)
# rep 0, T_train 496, pregret=0.5090
# (497, 57) (497,) (497,)
# rep 0, T_train 497, pregret=0.4852
# (498, 57) (498,) (498,)
# rep 0, T_train 498, pregret=0.8870
# (499, 57) (499,) (499,)
# rep 0, T_train 499, pregret=0.2511
# (500, 57) (500,) (500,)
# rep 0, T_train 500, pregret=0.5132
# (501, 57) (501,) (501,)
# rep 0, T_train 501, pregret=0.6151
# (502, 57) (502,) (502,)
# rep 0, T_train 502, pregret=0.3625
# (503, 57) (503,) (503,)
# rep 0, T_train 503, pregret=0.4201
# (504, 57) (504,) (504,)
# rep 0, T_train 504, pregret=0.6331
# (505, 57) (505,) (505,)
# rep 0, T_train 505, pregret=0.4849
# (506, 57) (506,) (506,)
# rep 0, T_train 506, pregret=0.6731
# (507, 57) (507,) (507,)
# rep 0, T_train 507, pregret=0.4158
# (508, 57) (508,) (508,)
# rep 0, T_train 508, pregret=0.3470
# (509, 57) (509,) (509,)
# rep 0, T_train 509, pregret=0.2253
# (510, 57) (510,) (510,)
# rep 0, T_train 510, pregret=0.6196
# (511, 57) (511,) (511,)
# rep 0, T_train 511, pregret=0.6370
# (512, 57) (512,) (512,)
# rep 0, T_train 512, pregret=0.4281
# (513, 57) (513,) (513,)
# rep 0, T_train 513, pregret=0.2745
# (514, 57) (514,) (514,)
# rep 0, T_train 514, pregret=0.4813
# (515, 57) (515,) (515,)
# rep 0, T_train 515, pregret=0.3265
# (516, 57) (516,) (516,)
# rep 0, T_train 516, pregret=0.5412
# (517, 57) (517,) (517,)
# rep 0, T_train 517, pregret=0.3904
# (518, 57) (518,) (518,)
# rep 0, T_train 518, pregret=0.9174
# (519, 57) (519,) (519,)
# rep 0, T_train 519, pregret=0.2951
# (520, 57) (520,) (520,)
# rep 0, T_train 520, pregret=0.6352
# (521, 57) (521,) (521,)
# rep 0, T_train 521, pregret=0.4791
# (522, 57) (522,) (522,)
# rep 0, T_train 522, pregret=0.8966
# (523, 57) (523,) (523,)
# rep 0, T_train 523, pregret=1.0115
# (524, 57) (524,) (524,)
# rep 0, T_train 524, pregret=0.8509
# (525, 57) (525,) (525,)
# rep 0, T_train 525, pregret=0.5633
# (526, 57) (526,) (526,)
# rep 0, T_train 526, pregret=0.5389
# (527, 57) (527,) (527,)
# rep 0, T_train 527, pregret=0.4031
# (528, 57) (528,) (528,)
# rep 0, T_train 528, pregret=0.5381
# (529, 57) (529,) (529,)
# rep 0, T_train 529, pregret=0.2650
# (530, 57) (530,) (530,)
# rep 0, T_train 530, pregret=0.7001
# (531, 57) (531,) (531,)
# rep 0, T_train 531, pregret=0.6122
# (532, 57) (532,) (532,)
# rep 0, T_train 532, pregret=0.2527
# (533, 57) (533,) (533,)
# rep 0, T_train 533, pregret=0.3232
# (534, 57) (534,) (534,)
# rep 0, T_train 534, pregret=0.7858
# (535, 57) (535,) (535,)
# rep 0, T_train 535, pregret=0.6779
# (536, 57) (536,) (536,)
# rep 0, T_train 536, pregret=0.9324
# (537, 57) (537,) (537,)
# rep 0, T_train 537, pregret=0.7096
# (538, 57) (538,) (538,)
# rep 0, T_train 538, pregret=0.0648
# (539, 57) (539,) (539,)
# rep 0, T_train 539, pregret=0.2339
# (540, 57) (540,) (540,)
# rep 0, T_train 540, pregret=0.6868
# (541, 57) (541,) (541,)
# rep 0, T_train 541, pregret=0.6151
# (542, 57) (542,) (542,)
# rep 0, T_train 542, pregret=0.1465
# (543, 57) (543,) (543,)
# rep 0, T_train 543, pregret=0.4757
# (544, 57) (544,) (544,)
# rep 0, T_train 544, pregret=0.2530
# (545, 57) (545,) (545,)
# rep 0, T_train 545, pregret=0.3655
# (546, 57) (546,) (546,)
# rep 0, T_train 546, pregret=0.5493
# (547, 57) (547,) (547,)
# rep 0, T_train 547, pregret=0.6533
# (548, 57) (548,) (548,)
# rep 0, T_train 548, pregret=0.4585
# (549, 57) (549,) (549,)
# rep 0, T_train 549, pregret=0.4447
# (550, 57) (550,) (550,)
# rep 0, T_train 550, pregret=0.0403
# (551, 57) (551,) (551,)
# rep 0, T_train 551, pregret=0.0659
# (552, 57) (552,) (552,)
# rep 0, T_train 552, pregret=0.2751
# (553, 57) (553,) (553,)
# rep 0, T_train 553, pregret=0.1571
# (554, 57) (554,) (554,)
# rep 0, T_train 554, pregret=0.4761
# (555, 57) (555,) (555,)
# rep 0, T_train 555, pregret=0.2983
# (556, 57) (556,) (556,)
# rep 0, T_train 556, pregret=0.4718
# (557, 57) (557,) (557,)
# rep 0, T_train 557, pregret=0.2005
# (558, 57) (558,) (558,)
# rep 0, T_train 558, pregret=0.3116
# (559, 57) (559,) (559,)
# rep 0, T_train 559, pregret=0.1700
# (560, 57) (560,) (560,)
# rep 0, T_train 560, pregret=0.6567
# (561, 57) (561,) (561,)
# rep 0, T_train 561, pregret=0.5039
# (562, 57) (562,) (562,)
# rep 0, T_train 562, pregret=0.3214
# (563, 57) (563,) (563,)
# rep 0, T_train 563, pregret=0.1872
# (564, 57) (564,) (564,)
# rep 0, T_train 564, pregret=0.1862
# (565, 57) (565,) (565,)
# rep 0, T_train 565, pregret=0.3299
# (566, 57) (566,) (566,)
# rep 0, T_train 566, pregret=1.0462
# (567, 57) (567,) (567,)
# rep 0, T_train 567, pregret=0.1089
# (568, 57) (568,) (568,)
# rep 0, T_train 568, pregret=0.2904
# (569, 57) (569,) (569,)
# rep 0, T_train 569, pregret=0.4854
# (570, 57) (570,) (570,)
# rep 0, T_train 570, pregret=0.2234
# (571, 57) (571,) (571,)
# rep 0, T_train 571, pregret=0.6838
# (572, 57) (572,) (572,)
# rep 0, T_train 572, pregret=0.4732
# (573, 57) (573,) (573,)
# rep 0, T_train 573, pregret=0.3386
# (574, 57) (574,) (574,)
# rep 0, T_train 574, pregret=0.3849
# (575, 57) (575,) (575,)
# rep 0, T_train 575, pregret=0.3489
# (576, 57) (576,) (576,)
# rep 0, T_train 576, pregret=1.1155
# (577, 57) (577,) (577,)
# rep 0, T_train 577, pregret=0.4709
# (578, 57) (578,) (578,)
# rep 0, T_train 578, pregret=0.6043
# (579, 57) (579,) (579,)
# rep 0, T_train 579, pregret=0.4502
# (580, 57) (580,) (580,)
# rep 0, T_train 580, pregret=0.4833
# (581, 57) (581,) (581,)
# rep 0, T_train 581, pregret=0.6505
# (582, 57) (582,) (582,)
# rep 0, T_train 582, pregret=0.7965
# (583, 57) (583,) (583,)
# rep 0, T_train 583, pregret=0.3657
# (584, 57) (584,) (584,)
# rep 0, T_train 584, pregret=0.3776
# (585, 57) (585,) (585,)
# rep 0, T_train 585, pregret=0.6761
# (586, 57) (586,) (586,)
# rep 0, T_train 586, pregret=0.4742
# (587, 57) (587,) (587,)
# rep 0, T_train 587, pregret=0.3993
# (588, 57) (588,) (588,)
# rep 0, T_train 588, pregret=0.4450
# (589, 57) (589,) (589,)
# rep 0, T_train 589, pregret=0.0800
# (590, 57) (590,) (590,)
# rep 0, T_train 590, pregret=0.1898
# (591, 57) (591,) (591,)
# rep 0, T_train 591, pregret=0.4516
# (592, 57) (592,) (592,)
# rep 0, T_train 592, pregret=0.3619
# (593, 57) (593,) (593,)
# rep 0, T_train 593, pregret=0.4176
# (594, 57) (594,) (594,)
# rep 0, T_train 594, pregret=0.6871
# (595, 57) (595,) (595,)
# rep 0, T_train 595, pregret=0.5547
# (596, 57) (596,) (596,)
# rep 0, T_train 596, pregret=0.2137
# (597, 57) (597,) (597,)
# rep 0, T_train 597, pregret=0.3336
# (598, 57) (598,) (598,)
# rep 0, T_train 598, pregret=0.3027
# (599, 57) (599,) (599,)
# rep 0, T_train 599, pregret=0.3403
# (600, 57) (600,) (600,)
# rep 0, T_train 600, pregret=0.8237
# (601, 57) (601,) (601,)
# rep 0, T_train 601, pregret=0.6000
# (602, 57) (602,) (602,)
# rep 0, T_train 602, pregret=0.6585
# (603, 57) (603,) (603,)
# rep 0, T_train 603, pregret=0.3014
# (604, 57) (604,) (604,)
# rep 0, T_train 604, pregret=0.7022
# (605, 57) (605,) (605,)
# rep 0, T_train 605, pregret=0.3188
# (606, 57) (606,) (606,)
# rep 0, T_train 606, pregret=0.5917
# (607, 57) (607,) (607,)
# rep 0, T_train 607, pregret=0.2383
# (608, 57) (608,) (608,)
# rep 0, T_train 608, pregret=0.1665
# (609, 57) (609,) (609,)
# rep 0, T_train 609, pregret=0.0193
# (610, 57) (610,) (610,)
# rep 0, T_train 610, pregret=0.7060
# (611, 57) (611,) (611,)
# rep 0, T_train 611, pregret=0.7415
# (612, 57) (612,) (612,)
# rep 0, T_train 612, pregret=0.2858
# (613, 57) (613,) (613,)
# rep 0, T_train 613, pregret=0.7549
# (614, 57) (614,) (614,)
# rep 0, T_train 614, pregret=0.4411
# (615, 57) (615,) (615,)
# rep 0, T_train 615, pregret=0.4327
# (616, 57) (616,) (616,)
# rep 0, T_train 616, pregret=0.5880
# (617, 57) (617,) (617,)
# rep 0, T_train 617, pregret=0.3292
# (618, 57) (618,) (618,)
# rep 0, T_train 618, pregret=0.4828
# (619, 57) (619,) (619,)
# rep 0, T_train 619, pregret=0.1916
# (620, 57) (620,) (620,)
# rep 0, T_train 620, pregret=0.4152
# (621, 57) (621,) (621,)
# rep 0, T_train 621, pregret=0.7937
# (622, 57) (622,) (622,)
# rep 0, T_train 622, pregret=0.8645
# (623, 57) (623,) (623,)
# rep 0, T_train 623, pregret=0.4604
# (624, 57) (624,) (624,)
# rep 0, T_train 624, pregret=0.2758
# (625, 57) (625,) (625,)
# rep 0, T_train 625, pregret=0.4519
# (626, 57) (626,) (626,)
# rep 0, T_train 626, pregret=0.5333
# (627, 57) (627,) (627,)
# rep 0, T_train 627, pregret=0.5294
# (628, 57) (628,) (628,)
# rep 0, T_train 628, pregret=0.6467
# (629, 57) (629,) (629,)
# rep 0, T_train 629, pregret=0.4855
# (630, 57) (630,) (630,)
# rep 0, T_train 630, pregret=0.3050
# (631, 57) (631,) (631,)
# rep 0, T_train 631, pregret=0.4671
# (632, 57) (632,) (632,)
# rep 0, T_train 632, pregret=0.4260
# (633, 57) (633,) (633,)
# rep 0, T_train 633, pregret=0.6136
# (634, 57) (634,) (634,)
# rep 0, T_train 634, pregret=0.4272
# (635, 57) (635,) (635,)
# rep 0, T_train 635, pregret=0.2497
# (636, 57) (636,) (636,)
# rep 0, T_train 636, pregret=0.1448
# (637, 57) (637,) (637,)
# rep 0, T_train 637, pregret=0.4227
# (638, 57) (638,) (638,)
# rep 0, T_train 638, pregret=0.4615
# (639, 57) (639,) (639,)
# rep 0, T_train 639, pregret=0.4602
# (640, 57) (640,) (640,)
# rep 0, T_train 640, pregret=0.3678
# (641, 57) (641,) (641,)
# rep 0, T_train 641, pregret=0.4685
# (642, 57) (642,) (642,)
# rep 0, T_train 642, pregret=0.4260
# (643, 57) (643,) (643,)
# rep 0, T_train 643, pregret=0.2106
# (644, 57) (644,) (644,)
# rep 0, T_train 644, pregret=0.6061
# (645, 57) (645,) (645,)
# rep 0, T_train 645, pregret=0.8313
# (646, 57) (646,) (646,)
# rep 0, T_train 646, pregret=0.9195
# (647, 57) (647,) (647,)
# rep 0, T_train 647, pregret=0.3411
# (648, 57) (648,) (648,)
# rep 0, T_train 648, pregret=0.7348
# (649, 57) (649,) (649,)
# rep 0, T_train 649, pregret=0.5605
# (650, 57) (650,) (650,)
# rep 0, T_train 650, pregret=0.4076
# (651, 57) (651,) (651,)
# rep 0, T_train 651, pregret=0.5137
# (652, 57) (652,) (652,)
# rep 0, T_train 652, pregret=0.3217
# (653, 57) (653,) (653,)
# rep 0, T_train 653, pregret=0.2706
# (654, 57) (654,) (654,)
# rep 0, T_train 654, pregret=0.4497
# (655, 57) (655,) (655,)
# rep 0, T_train 655, pregret=0.5322
# (656, 57) (656,) (656,)
# rep 0, T_train 656, pregret=0.1017
# (657, 57) (657,) (657,)
# rep 0, T_train 657, pregret=0.3557
# (658, 57) (658,) (658,)
# rep 0, T_train 658, pregret=0.1303
# (659, 57) (659,) (659,)
# rep 0, T_train 659, pregret=0.2452
# (660, 57) (660,) (660,)
# rep 0, T_train 660, pregret=0.3875
# (661, 57) (661,) (661,)
# rep 0, T_train 661, pregret=0.4700
# (662, 57) (662,) (662,)
# rep 0, T_train 662, pregret=0.9205
# (663, 57) (663,) (663,)
# rep 0, T_train 663, pregret=0.4197
# (664, 57) (664,) (664,)
# rep 0, T_train 664, pregret=0.4867
# (665, 57) (665,) (665,)
# rep 0, T_train 665, pregret=0.7668
# (666, 57) (666,) (666,)
# rep 0, T_train 666, pregret=0.4616
# (667, 57) (667,) (667,)
# rep 0, T_train 667, pregret=0.3148
# (668, 57) (668,) (668,)
# rep 0, T_train 668, pregret=0.2929
# (669, 57) (669,) (669,)
# rep 0, T_train 669, pregret=0.4009
# (670, 57) (670,) (670,)
# rep 0, T_train 670, pregret=0.2382
# (671, 57) (671,) (671,)
# rep 0, T_train 671, pregret=0.7840
# (672, 57) (672,) (672,)
# rep 0, T_train 672, pregret=0.2829
# (673, 57) (673,) (673,)
# rep 0, T_train 673, pregret=0.2234
# (674, 57) (674,) (674,)
# rep 0, T_train 674, pregret=0.6808
# (675, 57) (675,) (675,)
# rep 0, T_train 675, pregret=0.8052
# (676, 57) (676,) (676,)
# rep 0, T_train 676, pregret=0.2754
# (677, 57) (677,) (677,)
# rep 0, T_train 677, pregret=0.6474
# (678, 57) (678,) (678,)
# rep 0, T_train 678, pregret=0.2406
# (679, 57) (679,) (679,)
# rep 0, T_train 679, pregret=0.3289
# (680, 57) (680,) (680,)
# rep 0, T_train 680, pregret=0.5429
# (681, 57) (681,) (681,)
# rep 0, T_train 681, pregret=0.4085
# (682, 57) (682,) (682,)
# rep 0, T_train 682, pregret=0.3344
# (683, 57) (683,) (683,)
# rep 0, T_train 683, pregret=0.6020
# (684, 57) (684,) (684,)
# rep 0, T_train 684, pregret=0.4038
# (685, 57) (685,) (685,)
# rep 0, T_train 685, pregret=0.1801
# (686, 57) (686,) (686,)
# rep 0, T_train 686, pregret=0.3104
# (687, 57) (687,) (687,)
# rep 0, T_train 687, pregret=0.8796
# (688, 57) (688,) (688,)
# rep 0, T_train 688, pregret=0.0882
# (689, 57) (689,) (689,)
# rep 0, T_train 689, pregret=0.0250
# (690, 57) (690,) (690,)
# rep 0, T_train 690, pregret=0.4940
# (691, 57) (691,) (691,)
# rep 0, T_train 691, pregret=0.3951
# (692, 57) (692,) (692,)
# rep 0, T_train 692, pregret=0.6707
# (693, 57) (693,) (693,)
# rep 0, T_train 693, pregret=0.1266
# (694, 57) (694,) (694,)
# rep 0, T_train 694, pregret=0.3870
# (695, 57) (695,) (695,)
# rep 0, T_train 695, pregret=0.2611
# (696, 57) (696,) (696,)
# rep 0, T_train 696, pregret=0.5541
# (697, 57) (697,) (697,)
# rep 0, T_train 697, pregret=0.4886
# (698, 57) (698,) (698,)
# rep 0, T_train 698, pregret=0.7954
# (699, 57) (699,) (699,)
# rep 0, T_train 699, pregret=0.5699
# (700, 57) (700,) (700,)
# rep 0, T_train 700, pregret=0.6884
# (701, 57) (701,) (701,)
# rep 0, T_train 701, pregret=0.5652
# (702, 57) (702,) (702,)
# rep 0, T_train 702, pregret=0.6437
# (703, 57) (703,) (703,)
# rep 0, T_train 703, pregret=0.3031
# (704, 57) (704,) (704,)
# rep 0, T_train 704, pregret=0.1662
# (705, 57) (705,) (705,)
# rep 0, T_train 705, pregret=0.2385
# (706, 57) (706,) (706,)
# rep 0, T_train 706, pregret=0.2816
# (707, 57) (707,) (707,)
# rep 0, T_train 707, pregret=0.6368
# (708, 57) (708,) (708,)
# rep 0, T_train 708, pregret=0.5976
# (709, 57) (709,) (709,)
# rep 0, T_train 709, pregret=0.4316
# (710, 57) (710,) (710,)
# rep 0, T_train 710, pregret=0.4706
# (711, 57) (711,) (711,)
# rep 0, T_train 711, pregret=0.5536
# (712, 57) (712,) (712,)
# rep 0, T_train 712, pregret=0.6059
# (713, 57) (713,) (713,)
# rep 0, T_train 713, pregret=0.3934
# (714, 57) (714,) (714,)
# rep 0, T_train 714, pregret=0.2707
# (715, 57) (715,) (715,)
# rep 0, T_train 715, pregret=0.3383
# (716, 57) (716,) (716,)
# rep 0, T_train 716, pregret=0.5886
# (717, 57) (717,) (717,)
# rep 0, T_train 717, pregret=0.2745
# (718, 57) (718,) (718,)
# rep 0, T_train 718, pregret=0.2899
# (719, 57) (719,) (719,)
# rep 0, T_train 719, pregret=0.4095
# (720, 57) (720,) (720,)
# rep 0, T_train 720, pregret=0.5892
# (721, 57) (721,) (721,)
# rep 0, T_train 721, pregret=0.1881
# (722, 57) (722,) (722,)
# rep 0, T_train 722, pregret=0.7233
# (723, 57) (723,) (723,)
# rep 0, T_train 723, pregret=0.3679
# (724, 57) (724,) (724,)
# rep 0, T_train 724, pregret=0.6654
# (725, 57) (725,) (725,)
# rep 0, T_train 725, pregret=0.5411
# (726, 57) (726,) (726,)
# rep 0, T_train 726, pregret=0.6883
# (727, 57) (727,) (727,)
# rep 0, T_train 727, pregret=0.6865
# (728, 57) (728,) (728,)
# rep 0, T_train 728, pregret=0.3450
# (729, 57) (729,) (729,)
# rep 0, T_train 729, pregret=0.8347
# (730, 57) (730,) (730,)
# rep 0, T_train 730, pregret=0.5087
# (731, 57) (731,) (731,)
# rep 0, T_train 731, pregret=0.6070
# (732, 57) (732,) (732,)
# rep 0, T_train 732, pregret=0.6599
# (733, 57) (733,) (733,)
# rep 0, T_train 733, pregret=0.2193
# (734, 57) (734,) (734,)
# rep 0, T_train 734, pregret=0.3665
# (735, 57) (735,) (735,)
# rep 0, T_train 735, pregret=0.8160
# (736, 57) (736,) (736,)
# rep 0, T_train 736, pregret=0.2779
# (737, 57) (737,) (737,)
# rep 0, T_train 737, pregret=0.1102
# (738, 57) (738,) (738,)
# rep 0, T_train 738, pregret=0.2826
# (739, 57) (739,) (739,)
# rep 0, T_train 739, pregret=0.2845
# (740, 57) (740,) (740,)
# rep 0, T_train 740, pregret=0.5208
# (741, 57) (741,) (741,)
# rep 0, T_train 741, pregret=0.8515
# (742, 57) (742,) (742,)
# rep 0, T_train 742, pregret=0.4535
# (743, 57) (743,) (743,)
# rep 0, T_train 743, pregret=0.3328
# (744, 57) (744,) (744,)
# rep 0, T_train 744, pregret=0.4972
# (745, 57) (745,) (745,)
# rep 0, T_train 745, pregret=0.4132
# (746, 57) (746,) (746,)
# rep 0, T_train 746, pregret=0.6423
# (747, 57) (747,) (747,)
# rep 0, T_train 747, pregret=0.5569
# (748, 57) (748,) (748,)
# rep 0, T_train 748, pregret=0.6559
# (749, 57) (749,) (749,)
# rep 0, T_train 749, pregret=0.7799
# (750, 57) (750,) (750,)
# rep 0, T_train 750, pregret=0.6282
# (751, 57) (751,) (751,)
# rep 0, T_train 751, pregret=0.2626
# (752, 57) (752,) (752,)
# rep 0, T_train 752, pregret=0.4252
# (753, 57) (753,) (753,)
# rep 0, T_train 753, pregret=0.3291
# (754, 57) (754,) (754,)
# rep 0, T_train 754, pregret=0.5018
# (755, 57) (755,) (755,)
# rep 0, T_train 755, pregret=0.8950
# (756, 57) (756,) (756,)
# rep 0, T_train 756, pregret=0.1690
# (757, 57) (757,) (757,)
# rep 0, T_train 757, pregret=0.5647
# (758, 57) (758,) (758,)
# rep 0, T_train 758, pregret=0.4213
# (759, 57) (759,) (759,)
# rep 0, T_train 759, pregret=0.4127
# (760, 57) (760,) (760,)
# rep 0, T_train 760, pregret=0.8250
# (761, 57) (761,) (761,)
# rep 0, T_train 761, pregret=0.1708
# (762, 57) (762,) (762,)
# rep 0, T_train 762, pregret=0.2285
# (763, 57) (763,) (763,)
# rep 0, T_train 763, pregret=0.7262
# (764, 57) (764,) (764,)
# rep 0, T_train 764, pregret=0.1163
# (765, 57) (765,) (765,)
# rep 0, T_train 765, pregret=0.0606
# (766, 57) (766,) (766,)
# rep 0, T_train 766, pregret=0.4520
# (767, 57) (767,) (767,)
# rep 0, T_train 767, pregret=0.6021
# (768, 57) (768,) (768,)
# rep 0, T_train 768, pregret=0.3671
# (769, 57) (769,) (769,)
# rep 0, T_train 769, pregret=0.0062
# (770, 57) (770,) (770,)
# rep 0, T_train 770, pregret=0.6182
# (771, 57) (771,) (771,)
# rep 0, T_train 771, pregret=0.9444
# (772, 57) (772,) (772,)
# rep 0, T_train 772, pregret=0.5586
# (773, 57) (773,) (773,)
# rep 0, T_train 773, pregret=0.6852
# (774, 57) (774,) (774,)
# rep 0, T_train 774, pregret=0.6350
# (775, 57) (775,) (775,)
# rep 0, T_train 775, pregret=0.4080
# (776, 57) (776,) (776,)
# rep 0, T_train 776, pregret=0.3678
# (777, 57) (777,) (777,)
# rep 0, T_train 777, pregret=0.4453
# (778, 57) (778,) (778,)
# rep 0, T_train 778, pregret=0.8871
# (779, 57) (779,) (779,)
# rep 0, T_train 779, pregret=0.0682
# (780, 57) (780,) (780,)
# rep 0, T_train 780, pregret=0.5093
# (781, 57) (781,) (781,)
# rep 0, T_train 781, pregret=0.9959
# (782, 57) (782,) (782,)
# rep 0, T_train 782, pregret=0.3950
# (783, 57) (783,) (783,)
# rep 0, T_train 783, pregret=0.4102
# (784, 57) (784,) (784,)
# rep 0, T_train 784, pregret=0.4766
# (785, 57) (785,) (785,)
# rep 0, T_train 785, pregret=0.5986
# (786, 57) (786,) (786,)
# rep 0, T_train 786, pregret=0.3119
# (787, 57) (787,) (787,)
# rep 0, T_train 787, pregret=0.9019
# (788, 57) (788,) (788,)
# rep 0, T_train 788, pregret=0.3719
# (789, 57) (789,) (789,)
# rep 0, T_train 789, pregret=0.2514
# (790, 57) (790,) (790,)
# rep 0, T_train 790, pregret=0.2712
# (791, 57) (791,) (791,)
# rep 0, T_train 791, pregret=0.2625
# (792, 57) (792,) (792,)
# rep 0, T_train 792, pregret=0.3204
# (793, 57) (793,) (793,)
# rep 0, T_train 793, pregret=0.1623
# (794, 57) (794,) (794,)
# rep 0, T_train 794, pregret=0.5126
# (795, 57) (795,) (795,)
# rep 0, T_train 795, pregret=0.2162
# (796, 57) (796,) (796,)
# rep 0, T_train 796, pregret=0.4780
# (797, 57) (797,) (797,)
# rep 0, T_train 797, pregret=0.4309
# (798, 57) (798,) (798,)
# rep 0, T_train 798, pregret=0.3709
# (799, 57) (799,) (799,)
# rep 0, T_train 799, pregret=0.6144
# (800, 57) (800,) (800,)
# rep 0, T_train 800, pregret=0.4064
# (801, 57) (801,) (801,)
# rep 0, T_train 801, pregret=0.5796
# (802, 57) (802,) (802,)
# rep 0, T_train 802, pregret=0.2426
# (803, 57) (803,) (803,)
# rep 0, T_train 803, pregret=0.5215
# (804, 57) (804,) (804,)
# rep 0, T_train 804, pregret=0.5803
# (805, 57) (805,) (805,)
# rep 0, T_train 805, pregret=0.4651
# (806, 57) (806,) (806,)
# rep 0, T_train 806, pregret=0.2898
# (807, 57) (807,) (807,)
# rep 0, T_train 807, pregret=0.4810
# (808, 57) (808,) (808,)
# rep 0, T_train 808, pregret=0.2655
# (809, 57) (809,) (809,)
# rep 0, T_train 809, pregret=0.2274
# (810, 57) (810,) (810,)
# rep 0, T_train 810, pregret=0.3379
# (811, 57) (811,) (811,)
# rep 0, T_train 811, pregret=0.5133
# (812, 57) (812,) (812,)
# rep 0, T_train 812, pregret=1.0158
# (813, 57) (813,) (813,)
# rep 0, T_train 813, pregret=0.2511
# (814, 57) (814,) (814,)
# rep 0, T_train 814, pregret=0.3045
# (815, 57) (815,) (815,)
# rep 0, T_train 815, pregret=0.2843
# (816, 57) (816,) (816,)
# rep 0, T_train 816, pregret=0.6914
# (817, 57) (817,) (817,)
# rep 0, T_train 817, pregret=0.2848
# (818, 57) (818,) (818,)
# rep 0, T_train 818, pregret=0.8036
# (819, 57) (819,) (819,)
# rep 0, T_train 819, pregret=0.4277
# (820, 57) (820,) (820,)
# rep 0, T_train 820, pregret=0.2987
# (821, 57) (821,) (821,)
# rep 0, T_train 821, pregret=0.5825
# (822, 57) (822,) (822,)
# rep 0, T_train 822, pregret=0.5826
# (823, 57) (823,) (823,)
# rep 0, T_train 823, pregret=0.1851
# (824, 57) (824,) (824,)
# rep 0, T_train 824, pregret=0.2651
# (825, 57) (825,) (825,)
# rep 0, T_train 825, pregret=0.5393
# (826, 57) (826,) (826,)
# rep 0, T_train 826, pregret=0.1942
# (827, 57) (827,) (827,)
# rep 0, T_train 827, pregret=0.4785
# (828, 57) (828,) (828,)
# rep 0, T_train 828, pregret=0.2698
# (829, 57) (829,) (829,)
# rep 0, T_train 829, pregret=0.2264
# (830, 57) (830,) (830,)
# rep 0, T_train 830, pregret=0.2396
# (831, 57) (831,) (831,)
# rep 0, T_train 831, pregret=0.8896
# (832, 57) (832,) (832,)
# rep 0, T_train 832, pregret=0.4323
# (833, 57) (833,) (833,)
# rep 0, T_train 833, pregret=0.4925
# (834, 57) (834,) (834,)
# rep 0, T_train 834, pregret=0.3669
# (835, 57) (835,) (835,)
# rep 0, T_train 835, pregret=0.2952
# (836, 57) (836,) (836,)
# rep 0, T_train 836, pregret=0.5856
# (837, 57) (837,) (837,)
# rep 0, T_train 837, pregret=0.5080
# (838, 57) (838,) (838,)
# rep 0, T_train 838, pregret=0.1707
# (839, 57) (839,) (839,)
# rep 0, T_train 839, pregret=0.2297
# (840, 57) (840,) (840,)
# rep 0, T_train 840, pregret=0.5424
# (841, 57) (841,) (841,)
# rep 0, T_train 841, pregret=0.2165
# (842, 57) (842,) (842,)
# rep 0, T_train 842, pregret=0.3451
# (843, 57) (843,) (843,)
# rep 0, T_train 843, pregret=0.5450
# (844, 57) (844,) (844,)
# rep 0, T_train 844, pregret=0.5544
# (845, 57) (845,) (845,)
# rep 0, T_train 845, pregret=0.6184
# (846, 57) (846,) (846,)
# rep 0, T_train 846, pregret=0.6708
# (847, 57) (847,) (847,)
# rep 0, T_train 847, pregret=0.4055
# (848, 57) (848,) (848,)
# rep 0, T_train 848, pregret=0.5293
# (849, 57) (849,) (849,)
# rep 0, T_train 849, pregret=0.2490
# (850, 57) (850,) (850,)
# rep 0, T_train 850, pregret=0.2822
# (851, 57) (851,) (851,)
# rep 0, T_train 851, pregret=0.5221
# (852, 57) (852,) (852,)
# rep 0, T_train 852, pregret=0.3982
# (853, 57) (853,) (853,)
# rep 0, T_train 853, pregret=0.7080
# (854, 57) (854,) (854,)
# rep 0, T_train 854, pregret=0.3456
# (855, 57) (855,) (855,)
# rep 0, T_train 855, pregret=0.6193
# (856, 57) (856,) (856,)
# rep 0, T_train 856, pregret=0.6228
# (857, 57) (857,) (857,)
# rep 0, T_train 857, pregret=0.1329
# (858, 57) (858,) (858,)
# rep 0, T_train 858, pregret=0.3531
# (859, 57) (859,) (859,)
# rep 0, T_train 859, pregret=0.5720
# (860, 57) (860,) (860,)
# rep 0, T_train 860, pregret=0.2419
# (861, 57) (861,) (861,)
# rep 0, T_train 861, pregret=0.0422
# (862, 57) (862,) (862,)
# rep 0, T_train 862, pregret=0.3070
# (863, 57) (863,) (863,)
# rep 0, T_train 863, pregret=0.6517
# (864, 57) (864,) (864,)
# rep 0, T_train 864, pregret=0.3613
# (865, 57) (865,) (865,)
# rep 0, T_train 865, pregret=0.3676
# (866, 57) (866,) (866,)
# rep 0, T_train 866, pregret=0.4830
# (867, 57) (867,) (867,)
# rep 0, T_train 867, pregret=0.5845
# (868, 57) (868,) (868,)
# rep 0, T_train 868, pregret=0.2808
# (869, 57) (869,) (869,)
# rep 0, T_train 869, pregret=0.5568
# (870, 57) (870,) (870,)
# rep 0, T_train 870, pregret=0.1976
# (871, 57) (871,) (871,)
# rep 0, T_train 871, pregret=0.4657
# (872, 57) (872,) (872,)
# rep 0, T_train 872, pregret=0.7226
# (873, 57) (873,) (873,)
# rep 0, T_train 873, pregret=0.5158
# (874, 57) (874,) (874,)
# rep 0, T_train 874, pregret=0.2392
# (875, 57) (875,) (875,)
# rep 0, T_train 875, pregret=0.0299
# (876, 57) (876,) (876,)
# rep 0, T_train 876, pregret=0.4139
# (877, 57) (877,) (877,)
# rep 0, T_train 877, pregret=0.2113
# (878, 57) (878,) (878,)
# rep 0, T_train 878, pregret=0.4017
# (879, 57) (879,) (879,)
# rep 0, T_train 879, pregret=0.4099
# (880, 57) (880,) (880,)
# rep 0, T_train 880, pregret=0.3063
# (881, 57) (881,) (881,)
# rep 0, T_train 881, pregret=0.4112
# (882, 57) (882,) (882,)
# rep 0, T_train 882, pregret=0.6588
# (883, 57) (883,) (883,)
# rep 0, T_train 883, pregret=0.3813
# (884, 57) (884,) (884,)
# rep 0, T_train 884, pregret=0.3356
# (885, 57) (885,) (885,)
# rep 0, T_train 885, pregret=0.4580
# (886, 57) (886,) (886,)
# rep 0, T_train 886, pregret=0.4794
# (887, 57) (887,) (887,)
# rep 0, T_train 887, pregret=0.2517
# (888, 57) (888,) (888,)
# rep 0, T_train 888, pregret=0.2794
# (889, 57) (889,) (889,)
# rep 0, T_train 889, pregret=0.3728
# (890, 57) (890,) (890,)
# rep 0, T_train 890, pregret=0.1147
# (891, 57) (891,) (891,)
# rep 0, T_train 891, pregret=0.6227
# (892, 57) (892,) (892,)
# rep 0, T_train 892, pregret=0.0623
# (893, 57) (893,) (893,)
# rep 0, T_train 893, pregret=0.5532
# (894, 57) (894,) (894,)
# rep 0, T_train 894, pregret=0.2585
# (895, 57) (895,) (895,)
# rep 0, T_train 895, pregret=0.3974
# (896, 57) (896,) (896,)
# rep 0, T_train 896, pregret=0.1298
# (897, 57) (897,) (897,)
# rep 0, T_train 897, pregret=0.4287
# (898, 57) (898,) (898,)
# rep 0, T_train 898, pregret=0.3706
# (899, 57) (899,) (899,)
# rep 0, T_train 899, pregret=0.1429
# (900, 57) (900,) (900,)
# rep 0, T_train 900, pregret=0.7629
# (901, 57) (901,) (901,)
# rep 0, T_train 901, pregret=0.2560
# (902, 57) (902,) (902,)
# rep 0, T_train 902, pregret=0.4541
# (903, 57) (903,) (903,)
# rep 0, T_train 903, pregret=0.3292
# (904, 57) (904,) (904,)
# rep 0, T_train 904, pregret=0.4436
# (905, 57) (905,) (905,)
# rep 0, T_train 905, pregret=0.3704
# (906, 57) (906,) (906,)
# rep 0, T_train 906, pregret=0.6875
# (907, 57) (907,) (907,)
# rep 0, T_train 907, pregret=0.6067
# (908, 57) (908,) (908,)
# rep 0, T_train 908, pregret=0.5949
# (909, 57) (909,) (909,)
# rep 0, T_train 909, pregret=0.6171
# (910, 57) (910,) (910,)
# rep 0, T_train 910, pregret=0.1836
# (911, 57) (911,) (911,)
# rep 0, T_train 911, pregret=0.1906
# (912, 57) (912,) (912,)
# rep 0, T_train 912, pregret=0.0824
# (913, 57) (913,) (913,)
# rep 0, T_train 913, pregret=0.8114
# (914, 57) (914,) (914,)
# rep 0, T_train 914, pregret=0.3606
# (915, 57) (915,) (915,)
# rep 0, T_train 915, pregret=0.3400
# (916, 57) (916,) (916,)
# rep 0, T_train 916, pregret=0.4054
# (917, 57) (917,) (917,)
# rep 0, T_train 917, pregret=0.4664
# (918, 57) (918,) (918,)
# rep 0, T_train 918, pregret=0.4393
# (919, 57) (919,) (919,)
# rep 0, T_train 919, pregret=0.0978
# (920, 57) (920,) (920,)
# rep 0, T_train 920, pregret=0.0484
# (921, 57) (921,) (921,)
# rep 0, T_train 921, pregret=0.4411
# (922, 57) (922,) (922,)
# rep 0, T_train 922, pregret=0.3094
# (923, 57) (923,) (923,)
# rep 0, T_train 923, pregret=0.6431
# (924, 57) (924,) (924,)
# rep 0, T_train 924, pregret=0.2780
# (925, 57) (925,) (925,)
# rep 0, T_train 925, pregret=0.9234
# (926, 57) (926,) (926,)
# rep 0, T_train 926, pregret=0.3372
# (927, 57) (927,) (927,)
# rep 0, T_train 927, pregret=0.5272
# (928, 57) (928,) (928,)
# rep 0, T_train 928, pregret=0.3604
# (929, 57) (929,) (929,)
# rep 0, T_train 929, pregret=0.5623
# (930, 57) (930,) (930,)
# rep 0, T_train 930, pregret=0.1030
# (931, 57) (931,) (931,)
# rep 0, T_train 931, pregret=0.5273
# (932, 57) (932,) (932,)
# rep 0, T_train 932, pregret=0.1806
# (933, 57) (933,) (933,)
# rep 0, T_train 933, pregret=0.3021
# (934, 57) (934,) (934,)
# rep 0, T_train 934, pregret=0.7713
# (935, 57) (935,) (935,)
# rep 0, T_train 935, pregret=0.4355
# (936, 57) (936,) (936,)
# rep 0, T_train 936, pregret=0.7106
# (937, 57) (937,) (937,)
# rep 0, T_train 937, pregret=0.3326
# (938, 57) (938,) (938,)
# rep 0, T_train 938, pregret=0.5826
# (939, 57) (939,) (939,)
# rep 0, T_train 939, pregret=0.4181
# (940, 57) (940,) (940,)
# rep 0, T_train 940, pregret=0.9359
# (941, 57) (941,) (941,)
# rep 0, T_train 941, pregret=0.3886
# (942, 57) (942,) (942,)
# rep 0, T_train 942, pregret=0.2898
# (943, 57) (943,) (943,)
# rep 0, T_train 943, pregret=0.1933
# (944, 57) (944,) (944,)
# rep 0, T_train 944, pregret=0.4008
# (945, 57) (945,) (945,)
# rep 0, T_train 945, pregret=0.2302
# (946, 57) (946,) (946,)
# rep 0, T_train 946, pregret=0.2486
# (947, 57) (947,) (947,)
# rep 0, T_train 947, pregret=0.4985
# (948, 57) (948,) (948,)
# rep 0, T_train 948, pregret=0.6625
# (949, 57) (949,) (949,)
# rep 0, T_train 949, pregret=0.2917
# (950, 57) (950,) (950,)
# rep 0, T_train 950, pregret=0.7565
# (951, 57) (951,) (951,)
# rep 0, T_train 951, pregret=0.4159
# (952, 57) (952,) (952,)
# rep 0, T_train 952, pregret=0.5835
# (953, 57) (953,) (953,)
# rep 0, T_train 953, pregret=0.8187
# (954, 57) (954,) (954,)
# rep 0, T_train 954, pregret=0.1838
# (955, 57) (955,) (955,)
# rep 0, T_train 955, pregret=0.4596
# (956, 57) (956,) (956,)
# rep 0, T_train 956, pregret=0.2916
# (957, 57) (957,) (957,)
# rep 0, T_train 957, pregret=0.5025
# (958, 57) (958,) (958,)
# rep 0, T_train 958, pregret=0.6779
# (959, 57) (959,) (959,)
# rep 0, T_train 959, pregret=0.6439
# (960, 57) (960,) (960,)
# rep 0, T_train 960, pregret=0.2017
# (961, 57) (961,) (961,)
# rep 0, T_train 961, pregret=0.4460
# (962, 57) (962,) (962,)
# rep 0, T_train 962, pregret=0.6158
# (963, 57) (963,) (963,)
# rep 0, T_train 963, pregret=0.2977
# (964, 57) (964,) (964,)
# rep 0, T_train 964, pregret=0.4163
# (965, 57) (965,) (965,)
# rep 0, T_train 965, pregret=0.2866
# (966, 57) (966,) (966,)
# rep 0, T_train 966, pregret=0.0686
# (967, 57) (967,) (967,)
# rep 0, T_train 967, pregret=0.5292
# (968, 57) (968,) (968,)
# rep 0, T_train 968, pregret=0.1072
# (969, 57) (969,) (969,)
# rep 0, T_train 969, pregret=0.4331
# (970, 57) (970,) (970,)
# rep 0, T_train 970, pregret=0.3590
# (971, 57) (971,) (971,)
# rep 0, T_train 971, pregret=0.6719
# (972, 57) (972,) (972,)
# rep 0, T_train 972, pregret=0.8237
# (973, 57) (973,) (973,)
# rep 0, T_train 973, pregret=0.4664
# (974, 57) (974,) (974,)
# rep 0, T_train 974, pregret=0.6027
# (975, 57) (975,) (975,)
# rep 0, T_train 975, pregret=0.4411
# (976, 57) (976,) (976,)
# rep 0, T_train 976, pregret=0.5441
# (977, 57) (977,) (977,)
# rep 0, T_train 977, pregret=0.5001
# (978, 57) (978,) (978,)
# rep 0, T_train 978, pregret=0.4080
# (979, 57) (979,) (979,)
# rep 0, T_train 979, pregret=0.4215
# (980, 57) (980,) (980,)
# rep 0, T_train 980, pregret=0.6145
# (981, 57) (981,) (981,)
# rep 0, T_train 981, pregret=0.1777
# (982, 57) (982,) (982,)
# rep 0, T_train 982, pregret=0.4649
# (983, 57) (983,) (983,)
# rep 0, T_train 983, pregret=0.8545
# (984, 57) (984,) (984,)
# rep 0, T_train 984, pregret=0.3721
# (985, 57) (985,) (985,)
# rep 0, T_train 985, pregret=0.2617
# (986, 57) (986,) (986,)
# rep 0, T_train 986, pregret=0.3360
# (987, 57) (987,) (987,)
# rep 0, T_train 987, pregret=0.5088
# (988, 57) (988,) (988,)
# rep 0, T_train 988, pregret=0.6140
# (989, 57) (989,) (989,)
# rep 0, T_train 989, pregret=0.4107
# (990, 57) (990,) (990,)
# rep 0, T_train 990, pregret=0.4421
# (991, 57) (991,) (991,)
# rep 0, T_train 991, pregret=0.3135
# (992, 57) (992,) (992,)
# rep 0, T_train 992, pregret=0.0256
# (993, 57) (993,) (993,)
# rep 0, T_train 993, pregret=0.8102
# (994, 57) (994,) (994,)
# rep 0, T_train 994, pregret=0.4687
# (995, 57) (995,) (995,)
# rep 0, T_train 995, pregret=0.7480
# (996, 57) (996,) (996,)
# rep 0, T_train 996, pregret=0.2737
# (997, 57) (997,) (997,)
# rep 0, T_train 997, pregret=0.0267
# (998, 57) (998,) (998,)
# rep 0, T_train 998, pregret=0.0932
# (999, 57) (999,) (999,)
# rep 0, T_train 999, pregret=0.0116
# (1000, 57) (1000,) (1000,)
# rep 0, T_train 1000, pregret=0.3652
# (1001, 57) (1001,) (1001,)
# rep 0, T_train 1001, pregret=0.5041
# (1002, 57) (1002,) (1002,)
# rep 0, T_train 1002, pregret=0.5630
# (1003, 57) (1003,) (1003,)
# rep 0, T_train 1003, pregret=0.7593
# (1004, 57) (1004,) (1004,)
# rep 0, T_train 1004, pregret=0.2663
# (1005, 57) (1005,) (1005,)
# rep 0, T_train 1005, pregret=0.3489
# (1006, 57) (1006,) (1006,)
# rep 0, T_train 1006, pregret=0.4415
# (1007, 57) (1007,) (1007,)
# rep 0, T_train 1007, pregret=0.4427
# (1008, 57) (1008,) (1008,)
# rep 0, T_train 1008, pregret=0.4277
# (1009, 57) (1009,) (1009,)
# rep 0, T_train 1009, pregret=0.6752
# (1010, 57) (1010,) (1010,)
# rep 0, T_train 1010, pregret=0.1228
# (1011, 57) (1011,) (1011,)
# rep 0, T_train 1011, pregret=0.1985
# (1012, 57) (1012,) (1012,)
# rep 0, T_train 1012, pregret=0.1102
# (1013, 57) (1013,) (1013,)
# ...
# (944, 57) (944,) (944,)
# rep 9, T_train 944, pregret=0.4819
# (945, 57) (945,) (945,)
# rep 9, T_train 945, pregret=0.5689
# (946, 57) (946,) (946,)
# rep 9, T_train 946, pregret=0.6719
# (947, 57) (947,) (947,)
# rep 9, T_train 947, pregret=0.2365
# (948, 57) (948,) (948,)
# rep 9, T_train 948, pregret=0.2239
# (949, 57) (949,) (949,)
# rep 9, T_train 949, pregret=0.1388
# (950, 57) (950,) (950,)
# rep 9, T_train 950, pregret=0.2974
# (951, 57) (951,) (951,)
# rep 9, T_train 951, pregret=0.1053
# (952, 57) (952,) (952,)
# rep 9, T_train 952, pregret=0.1693
# (953, 57) (953,) (953,)
# rep 9, T_train 953, pregret=0.4671
# (954, 57) (954,) (954,)
# rep 9, T_train 954, pregret=0.6417
# (955, 57) (955,) (955,)
# rep 9, T_train 955, pregret=0.3289
# (956, 57) (956,) (956,)
# rep 9, T_train 956, pregret=0.4426
# (957, 57) (957,) (957,)
# rep 9, T_train 957, pregret=0.3511
# (958, 57) (958,) (958,)
# rep 9, T_train 958, pregret=0.4361
# (959, 57) (959,) (959,)
# rep 9, T_train 959, pregret=0.4725
# (960, 57) (960,) (960,)
# rep 9, T_train 960, pregret=0.4871
# (961, 57) (961,) (961,)
# rep 9, T_train 961, pregret=0.3455
# (962, 57) (962,) (962,)
# rep 9, T_train 962, pregret=0.4006
# (963, 57) (963,) (963,)
# rep 9, T_train 963, pregret=0.3721
# (964, 57) (964,) (964,)
# rep 9, T_train 964, pregret=0.2829
# (965, 57) (965,) (965,)
# rep 9, T_train 965, pregret=0.6805
# (966, 57) (966,) (966,)
# rep 9, T_train 966, pregret=0.4937
# (967, 57) (967,) (967,)
# rep 9, T_train 967, pregret=0.2835
# (968, 57) (968,) (968,)
# rep 9, T_train 968, pregret=0.5762
# (969, 57) (969,) (969,)
# rep 9, T_train 969, pregret=0.2016
# (970, 57) (970,) (970,)
# rep 9, T_train 970, pregret=0.5640
# (971, 57) (971,) (971,)
# rep 9, T_train 971, pregret=0.0264
# (972, 57) (972,) (972,)
# rep 9, T_train 972, pregret=0.4794
# (973, 57) (973,) (973,)
# rep 9, T_train 973, pregret=0.5161
# (974, 57) (974,) (974,)
# rep 9, T_train 974, pregret=0.0343
# (975, 57) (975,) (975,)
# rep 9, T_train 975, pregret=0.2277
# (976, 57) (976,) (976,)
# rep 9, T_train 976, pregret=0.1857
# (977, 57) (977,) (977,)
# rep 9, T_train 977, pregret=0.4164
# (978, 57) (978,) (978,)
# rep 9, T_train 978, pregret=0.3768
# (979, 57) (979,) (979,)
# rep 9, T_train 979, pregret=0.3257
# (980, 57) (980,) (980,)
# rep 9, T_train 980, pregret=0.8724
# (981, 57) (981,) (981,)
# rep 9, T_train 981, pregret=0.3840
# (982, 57) (982,) (982,)
# rep 9, T_train 982, pregret=0.6449
# (983, 57) (983,) (983,)
# rep 9, T_train 983, pregret=0.2654
# (984, 57) (984,) (984,)
# rep 9, T_train 984, pregret=0.5298
# (985, 57) (985,) (985,)
# rep 9, T_train 985, pregret=0.5925
# (986, 57) (986,) (986,)
# rep 9, T_train 986, pregret=0.4006
# (987, 57) (987,) (987,)
# rep 9, T_train 987, pregret=0.3704
# (988, 57) (988,) (988,)
# rep 9, T_train 988, pregret=0.2682
# (989, 57) (989,) (989,)
# rep 9, T_train 989, pregret=0.1571
# (990, 57) (990,) (990,)
# rep 9, T_train 990, pregret=0.2953
# (991, 57) (991,) (991,)
# rep 9, T_train 991, pregret=0.5407
# (992, 57) (992,) (992,)
# rep 9, T_train 992, pregret=0.4797
# (993, 57) (993,) (993,)
# rep 9, T_train 993, pregret=0.5340
# (994, 57) (994,) (994,)
# rep 9, T_train 994, pregret=0.4949
# (995, 57) (995,) (995,)
# rep 9, T_train 995, pregret=0.2811
# (996, 57) (996,) (996,)
# rep 9, T_train 996, pregret=0.4591
# (997, 57) (997,) (997,)
# rep 9, T_train 997, pregret=0.0545
# (998, 57) (998,) (998,)
# rep 9, T_train 998, pregret=0.3878
# (999, 57) (999,) (999,)
# rep 9, T_train 999, pregret=0.1377
# (1000, 57) (1000,) (1000,)
# rep 9, T_train 1000, pregret=0.3010
# (1001, 57) (1001,) (1001,)
# rep 9, T_train 1001, pregret=0.2030
# (1002, 57) (1002,) (1002,)
# rep 9, T_train 1002, pregret=0.4206
# (1003, 57) (1003,) (1003,)
# rep 9, T_train 1003, pregret=0.7812
# (1004, 57) (1004,) (1004,)
# rep 9, T_train 1004, pregret=0.3223
# (1005, 57) (1005,) (1005,)
# rep 9, T_train 1005, pregret=0.3072
# (1006, 57) (1006,) (1006,)
# rep 9, T_train 1006, pregret=0.4653
# (1007, 57) (1007,) (1007,)
# rep 9, T_train 1007, pregret=0.5378
# (1008, 57) (1008,) (1008,)
# rep 9, T_train 1008, pregret=0.8884
# (1009, 57) (1009,) (1009,)
# rep 9, T_train 1009, pregret=0.6112
# (1010, 57) (1010,) (1010,)
# rep 9, T_train 1010, pregret=0.3249
# (1011, 57) (1011,) (1011,)
# rep 9, T_train 1011, pregret=0.5986
# (1012, 57) (1012,) (1012,)
# rep 9, T_train 1012, pregret=0.0907
# (1013, 57) (1013,) (1013,)
# rep 9, T_train 1013, pregret=0.2725
# (1014, 57) (1014,) (1014,)
# rep 9, T_train 1014, pregret=0.1946
# (1015, 57) (1015,) (1015,)
# rep 9, T_train 1015, pregret=0.4427
# (1016, 57) (1016,) (1016,)
# rep 9, T_train 1016, pregret=0.8816
# (1017, 57) (1017,) (1017,)
# rep 9, T_train 1017, pregret=0.2712
# (1018, 57) (1018,) (1018,)
# rep 9, T_train 1018, pregret=0.5058
# (1019, 57) (1019,) (1019,)
# rep 9, T_train 1019, pregret=0.9011
# (1020, 57) (1020,) (1020,)
# rep 9, T_train 1020, pregret=0.3347
# (1021, 57) (1021,) (1021,)
# rep 9, T_train 1021, pregret=0.0320
# (1022, 57) (1022,) (1022,)
# rep 9, T_train 1022, pregret=0.4581
# (1023, 57) (1023,) (1023,)
# rep 9, T_train 1023, pregret=0.4130
# (1024, 57) (1024,) (1024,)
# rep 9, T_train 1024, pregret=0.6099
# (1025, 57) (1025,) (1025,)
# rep 9, T_train 1025, pregret=0.6233
# (1026, 57) (1026,) (1026,)
# rep 9, T_train 1026, pregret=0.2883
# (1027, 57) (1027,) (1027,)
# rep 9, T_train 1027, pregret=0.6788
# (1028, 57) (1028,) (1028,)
# rep 9, T_train 1028, pregret=0.0591
# (1029, 57) (1029,) (1029,)
# rep 9, T_train 1029, pregret=0.2347
# (1030, 57) (1030,) (1030,)
# rep 9, T_train 1030, pregret=0.2982
# (1031, 57) (1031,) (1031,)
# rep 9, T_train 1031, pregret=0.2113
# (1032, 57) (1032,) (1032,)
# rep 9, T_train 1032, pregret=0.5566
# (1033, 57) (1033,) (1033,)
# rep 9, T_train 1033, pregret=0.5239
# (1034, 57) (1034,) (1034,)
# rep 9, T_train 1034, pregret=0.6663
# (1035, 57) (1035,) (1035,)
# rep 9, T_train 1035, pregret=0.8029
# (1036, 57) (1036,) (1036,)
# rep 9, T_train 1036, pregret=0.5017
# (1037, 57) (1037,) (1037,)
# rep 9, T_train 1037, pregret=0.5234
# (1038, 57) (1038,) (1038,)
# rep 9, T_train 1038, pregret=0.1616
# (1039, 57) (1039,) (1039,)
# rep 9, T_train 1039, pregret=0.5594
# (1040, 57) (1040,) (1040,)
# rep 9, T_train 1040, pregret=0.2234
# (1041, 57) (1041,) (1041,)
# rep 9, T_train 1041, pregret=0.5398
# (1042, 57) (1042,) (1042,)
# rep 9, T_train 1042, pregret=0.1490
# (1043, 57) (1043,) (1043,)
# rep 9, T_train 1043, pregret=0.0908
# (1044, 57) (1044,) (1044,)
# rep 9, T_train 1044, pregret=0.6120
# (1045, 57) (1045,) (1045,)
# rep 9, T_train 1045, pregret=1.0543
# (1046, 57) (1046,) (1046,)
# rep 9, T_train 1046, pregret=0.1728
# (1047, 57) (1047,) (1047,)
# rep 9, T_train 1047, pregret=0.4803
# (1048, 57) (1048,) (1048,)
# rep 9, T_train 1048, pregret=0.7681
# (1049, 57) (1049,) (1049,)
# rep 9, T_train 1049, pregret=0.4033
# (1050, 57) (1050,) (1050,)
# rep 9, T_train 1050, pregret=0.0947
# (1051, 57) (1051,) (1051,)
# rep 9, T_train 1051, pregret=0.0850
# (1052, 57) (1052,) (1052,)
# rep 9, T_train 1052, pregret=0.7599
# (1053, 57) (1053,) (1053,)
# rep 9, T_train 1053, pregret=0.4100
# (1054, 57) (1054,) (1054,)
# rep 9, T_train 1054, pregret=0.4285
# (1055, 57) (1055,) (1055,)
# rep 9, T_train 1055, pregret=0.0202
# (1056, 57) (1056,) (1056,)
# rep 9, T_train 1056, pregret=0.6079
# (1057, 57) (1057,) (1057,)
# rep 9, T_train 1057, pregret=0.3918
# (1058, 57) (1058,) (1058,)
# rep 9, T_train 1058, pregret=0.2558
# (1059, 57) (1059,) (1059,)
# rep 9, T_train 1059, pregret=0.1765
# (1060, 57) (1060,) (1060,)
# rep 9, T_train 1060, pregret=0.7177
# (1061, 57) (1061,) (1061,)
# rep 9, T_train 1061, pregret=0.6333
# (1062, 57) (1062,) (1062,)
# rep 9, T_train 1062, pregret=0.2647
# (1063, 57) (1063,) (1063,)
# rep 9, T_train 1063, pregret=0.2007
# (1064, 57) (1064,) (1064,)
# rep 9, T_train 1064, pregret=0.3630
# (1065, 57) (1065,) (1065,)
# rep 9, T_train 1065, pregret=0.5391
# (1066, 57) (1066,) (1066,)
# rep 9, T_train 1066, pregret=0.4221
# (1067, 57) (1067,) (1067,)
# rep 9, T_train 1067, pregret=0.5667
# (1068, 57) (1068,) (1068,)
# rep 9, T_train 1068, pregret=0.2556
# (1069, 57) (1069,) (1069,)
# rep 9, T_train 1069, pregret=0.7533
# (1070, 57) (1070,) (1070,)
# rep 9, T_train 1070, pregret=0.4459
# (1071, 57) (1071,) (1071,)
# rep 9, T_train 1071, pregret=0.9458
# (1072, 57) (1072,) (1072,)
# rep 9, T_train 1072, pregret=0.4419
# (1073, 57) (1073,) (1073,)
# rep 9, T_train 1073, pregret=0.3536
# (1074, 57) (1074,) (1074,)
# rep 9, T_train 1074, pregret=0.4463
# (1075, 57) (1075,) (1075,)
# rep 9, T_train 1075, pregret=0.3301
# (1076, 57) (1076,) (1076,)
# rep 9, T_train 1076, pregret=0.0796
# (1077, 57) (1077,) (1077,)
# rep 9, T_train 1077, pregret=0.2876
# (1078, 57) (1078,) (1078,)
# rep 9, T_train 1078, pregret=0.2020
# (1079, 57) (1079,) (1079,)
# rep 9, T_train 1079, pregret=0.7139
# (1080, 57) (1080,) (1080,)
# rep 9, T_train 1080, pregret=0.4226
# (1081, 57) (1081,) (1081,)
# rep 9, T_train 1081, pregret=0.2068
# (1082, 57) (1082,) (1082,)
# rep 9, T_train 1082, pregret=0.3441
# (1083, 57) (1083,) (1083,)
# rep 9, T_train 1083, pregret=0.3470
# (1084, 57) (1084,) (1084,)
# rep 9, T_train 1084, pregret=0.5293
# (1085, 57) (1085,) (1085,)
# rep 9, T_train 1085, pregret=0.4448
# (1086, 57) (1086,) (1086,)
# rep 9, T_train 1086, pregret=0.2391
# (1087, 57) (1087,) (1087,)
# rep 9, T_train 1087, pregret=0.4471
# (1088, 57) (1088,) (1088,)
# rep 9, T_train 1088, pregret=0.8765
# (1089, 57) (1089,) (1089,)
# rep 9, T_train 1089, pregret=0.3589
# (1090, 57) (1090,) (1090,)
# rep 9, T_train 1090, pregret=0.6002
# (1091, 57) (1091,) (1091,)
# rep 9, T_train 1091, pregret=0.2945
# (1092, 57) (1092,) (1092,)
# rep 9, T_train 1092, pregret=0.2265
# (1093, 57) (1093,) (1093,)
# rep 9, T_train 1093, pregret=0.3749
# (1094, 57) (1094,) (1094,)
# rep 9, T_train 1094, pregret=0.5354
# (1095, 57) (1095,) (1095,)
# rep 9, T_train 1095, pregret=0.2386
# (1096, 57) (1096,) (1096,)
# rep 9, T_train 1096, pregret=0.1767
# (1097, 57) (1097,) (1097,)
# rep 9, T_train 1097, pregret=0.3668
# (1098, 57) (1098,) (1098,)
# rep 9, T_train 1098, pregret=0.0527
# (1099, 57) (1099,) (1099,)
# rep 9, T_train 1099, pregret=0.5029
# (1100, 57) (1100,) (1100,)
# rep 9, T_train 1100, pregret=0.1015
# (1101, 57) (1101,) (1101,)
# rep 9, T_train 1101, pregret=0.1930
# (1102, 57) (1102,) (1102,)
# rep 9, T_train 1102, pregret=0.2488
# (1103, 57) (1103,) (1103,)
# rep 9, T_train 1103, pregret=0.4921
# (1104, 57) (1104,) (1104,)
# rep 9, T_train 1104, pregret=0.3023
# (1105, 57) (1105,) (1105,)
# rep 9, T_train 1105, pregret=0.4550
# (1106, 57) (1106,) (1106,)
# rep 9, T_train 1106, pregret=0.5081
# (1107, 57) (1107,) (1107,)
# rep 9, T_train 1107, pregret=0.5709
# (1108, 57) (1108,) (1108,)
# rep 9, T_train 1108, pregret=0.0918
# (1109, 57) (1109,) (1109,)
# rep 9, T_train 1109, pregret=0.6603
# (1110, 57) (1110,) (1110,)
# rep 9, T_train 1110, pregret=0.6000
# (1111, 57) (1111,) (1111,)
# rep 9, T_train 1111, pregret=0.9318
# (1112, 57) (1112,) (1112,)
# rep 9, T_train 1112, pregret=0.2331
# (1113, 57) (1113,) (1113,)
# rep 9, T_train 1113, pregret=0.3006
# (1114, 57) (1114,) (1114,)
# rep 9, T_train 1114, pregret=0.4642
# (1115, 57) (1115,) (1115,)
# rep 9, T_train 1115, pregret=0.8350
# (1116, 57) (1116,) (1116,)
# rep 9, T_train 1116, pregret=0.7116
# (1117, 57) (1117,) (1117,)
# rep 9, T_train 1117, pregret=0.2853
# (1118, 57) (1118,) (1118,)
# rep 9, T_train 1118, pregret=0.6753
# (1119, 57) (1119,) (1119,)
# rep 9, T_train 1119, pregret=0.2730
# (1120, 57) (1120,) (1120,)
# rep 9, T_train 1120, pregret=0.3442
# (1121, 57) (1121,) (1121,)
# rep 9, T_train 1121, pregret=0.5395
# (1122, 57) (1122,) (1122,)
# rep 9, T_train 1122, pregret=0.2010
# (1123, 57) (1123,) (1123,)
# rep 9, T_train 1123, pregret=0.6418
# (1124, 57) (1124,) (1124,)
# rep 9, T_train 1124, pregret=0.7832
# (1125, 57) (1125,) (1125,)
# rep 9, T_train 1125, pregret=0.3386
# (1126, 57) (1126,) (1126,)
# rep 9, T_train 1126, pregret=0.2011
# (1127, 57) (1127,) (1127,)
# rep 9, T_train 1127, pregret=0.3873
# (1128, 57) (1128,) (1128,)
# rep 9, T_train 1128, pregret=0.4438
# (1129, 57) (1129,) (1129,)
# rep 9, T_train 1129, pregret=0.5068
# (1130, 57) (1130,) (1130,)
# rep 9, T_train 1130, pregret=0.5828
# (1131, 57) (1131,) (1131,)
# rep 9, T_train 1131, pregret=0.2259
# (1132, 57) (1132,) (1132,)
# rep 9, T_train 1132, pregret=0.7716
# (1133, 57) (1133,) (1133,)
# rep 9, T_train 1133, pregret=0.5511
# (1134, 57) (1134,) (1134,)
# rep 9, T_train 1134, pregret=0.1736
# (1135, 57) (1135,) (1135,)
# rep 9, T_train 1135, pregret=0.3476
# (1136, 57) (1136,) (1136,)
# rep 9, T_train 1136, pregret=0.7699
# (1137, 57) (1137,) (1137,)
# rep 9, T_train 1137, pregret=0.3410
# (1138, 57) (1138,) (1138,)
# rep 9, T_train 1138, pregret=0.5689
# (1139, 57) (1139,) (1139,)
# rep 9, T_train 1139, pregret=0.2416
# (1140, 57) (1140,) (1140,)
# rep 9, T_train 1140, pregret=0.4188
# (1141, 57) (1141,) (1141,)
# rep 9, T_train 1141, pregret=0.3622
# (1142, 57) (1142,) (1142,)
# rep 9, T_train 1142, pregret=0.5041
# (1143, 57) (1143,) (1143,)
# rep 9, T_train 1143, pregret=0.6074
# (1144, 57) (1144,) (1144,)
# rep 9, T_train 1144, pregret=0.2413
# (1145, 57) (1145,) (1145,)
# rep 9, T_train 1145, pregret=0.2409
# (1146, 57) (1146,) (1146,)
# rep 9, T_train 1146, pregret=0.4608
# (1147, 57) (1147,) (1147,)
# rep 9, T_train 1147, pregret=0.2256
# (1148, 57) (1148,) (1148,)
# rep 9, T_train 1148, pregret=0.1846
# (1149, 57) (1149,) (1149,)
# rep 9, T_train 1149, pregret=0.4453
# (1150, 57) (1150,) (1150,)
# rep 9, T_train 1150, pregret=0.5010
# (1151, 57) (1151,) (1151,)
# rep 9, T_train 1151, pregret=0.3734
# (1152, 57) (1152,) (1152,)
# rep 9, T_train 1152, pregret=0.6828
# (1153, 57) (1153,) (1153,)
# rep 9, T_train 1153, pregret=0.3445
# (1154, 57) (1154,) (1154,)
# rep 9, T_train 1154, pregret=0.6914
# (1155, 57) (1155,) (1155,)
# rep 9, T_train 1155, pregret=0.2447
# (1156, 57) (1156,) (1156,)
# rep 9, T_train 1156, pregret=0.5509
# (1157, 57) (1157,) (1157,)
# rep 9, T_train 1157, pregret=0.4481
# (1158, 57) (1158,) (1158,)
# rep 9, T_train 1158, pregret=0.4429
# (1159, 57) (1159,) (1159,)
# rep 9, T_train 1159, pregret=0.2691
# (1160, 57) (1160,) (1160,)
# rep 9, T_train 1160, pregret=0.2444
# (1161, 57) (1161,) (1161,)
# rep 9, T_train 1161, pregret=0.5505
# (1162, 57) (1162,) (1162,)
# rep 9, T_train 1162, pregret=0.4653
# (1163, 57) (1163,) (1163,)
# rep 9, T_train 1163, pregret=0.5937
# (1164, 57) (1164,) (1164,)
# rep 9, T_train 1164, pregret=0.2988
# (1165, 57) (1165,) (1165,)
# rep 9, T_train 1165, pregret=0.4635
# (1166, 57) (1166,) (1166,)
# rep 9, T_train 1166, pregret=0.3456
# (1167, 57) (1167,) (1167,)
# rep 9, T_train 1167, pregret=0.3449
# (1168, 57) (1168,) (1168,)
# rep 9, T_train 1168, pregret=0.7598
# (1169, 57) (1169,) (1169,)
# rep 9, T_train 1169, pregret=0.3535
# (1170, 57) (1170,) (1170,)
# rep 9, T_train 1170, pregret=0.2023
# (1171, 57) (1171,) (1171,)
# rep 9, T_train 1171, pregret=0.3479
# (1172, 57) (1172,) (1172,)
# rep 9, T_train 1172, pregret=0.4539
# (1173, 57) (1173,) (1173,)
# rep 9, T_train 1173, pregret=0.3662
# (1174, 57) (1174,) (1174,)
# rep 9, T_train 1174, pregret=0.4851
# (1175, 57) (1175,) (1175,)
# rep 9, T_train 1175, pregret=0.5549
# (1176, 57) (1176,) (1176,)
# rep 9, T_train 1176, pregret=0.7912
# (1177, 57) (1177,) (1177,)
# rep 9, T_train 1177, pregret=0.6251
# (1178, 57) (1178,) (1178,)
# rep 9, T_train 1178, pregret=0.6327
# (1179, 57) (1179,) (1179,)
# rep 9, T_train 1179, pregret=0.1006
# (1180, 57) (1180,) (1180,)
# rep 9, T_train 1180, pregret=0.5278
# (1181, 57) (1181,) (1181,)
# rep 9, T_train 1181, pregret=1.0996
# (1182, 57) (1182,) (1182,)
# rep 9, T_train 1182, pregret=0.5456
# (1183, 57) (1183,) (1183,)
# rep 9, T_train 1183, pregret=0.3447
# (1184, 57) (1184,) (1184,)
# rep 9, T_train 1184, pregret=0.2596
# (1185, 57) (1185,) (1185,)
# rep 9, T_train 1185, pregret=0.1036
# (1186, 57) (1186,) (1186,)
# rep 9, T_train 1186, pregret=0.5104
# (1187, 57) (1187,) (1187,)
# rep 9, T_train 1187, pregret=0.2932
# (1188, 57) (1188,) (1188,)
# rep 9, T_train 1188, pregret=0.5240
# (1189, 57) (1189,) (1189,)
# rep 9, T_train 1189, pregret=0.5700
# (1190, 57) (1190,) (1190,)
# rep 9, T_train 1190, pregret=0.2945
# (1191, 57) (1191,) (1191,)
# rep 9, T_train 1191, pregret=0.3662
# (1192, 57) (1192,) (1192,)
# rep 9, T_train 1192, pregret=0.4047
# (1193, 57) (1193,) (1193,)
# rep 9, T_train 1193, pregret=0.3652
# (1194, 57) (1194,) (1194,)
# rep 9, T_train 1194, pregret=0.1300
# (1195, 57) (1195,) (1195,)
# rep 9, T_train 1195, pregret=0.3824
# (1196, 57) (1196,) (1196,)
# rep 9, T_train 1196, pregret=0.3072
# (1197, 57) (1197,) (1197,)
# rep 9, T_train 1197, pregret=0.1437
# (1198, 57) (1198,) (1198,)
# rep 9, T_train 1198, pregret=0.3880
# (1199, 57) (1199,) (1199,)
# rep 9, T_train 1199, pregret=0.5445
# (1200, 57) (1200,) (1200,)
# rep 9, T_train 1200, pregret=0.1566

# %%
PREGRETS_arr = np.vstack(PREGRETS)
PREGRETS_random_arr = np.vstack(PREGRETS_random)
np.savez(
    f"../results/OnlinePAFM/stochastic_PVAFM_GBT_onlineoffline_gamma0.9_oh_w_time200_1200_lookahead{6}_10reps.npz",
    pregrets_online = PREGRETS_arr,
    pregrets_offline = PREGRETS_random_arr
    )
